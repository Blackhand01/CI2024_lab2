# %% [markdown]
# # Traveling Salesman Problem (TSP) - Genetic and Greedy Algorithms
#
# This notebook presents comprehensive implementations of both Genetic and Greedy algorithms to solve the **Traveling Salesman Problem (TSP)**. The TSP is a classic optimization problem aiming to find the shortest possible route that visits a set of cities exactly once and returns to the origin city.
#
# ### Table of Contents
# 1. [Introduction](#Introduction)
# 2. [Importing Libraries](#Importing-Libraries)
# 3. [Utility Functions](#Utility-Functions)
#     - [Distance Matrix Creation](#Distance-Matrix-Creation)
#     - [TSP Cost Calculation](#TSP-Cost-Calculation)
#     - [Adaptive Population Size](#Adaptive-Population-Size)
#     - [Population Initialization](#Population-Initialization)
#     - [Selection Mechanism](#Selection-Mechanism)
#     - [Crossover and Mutation](#Crossover-and-Mutation)
# 4. [Genetic Algorithm Implementation](#Genetic-Algorithm-Implementation)
# 5. [Greedy Algorithm Implementation](#Greedy-Algorithm-Implementation)
# 6. [Running Experiments](#Running-Experiments)
# 7. [Results and Analysis](#Results-and-Analysis)
# 8. [Plotting Progressions](#Plotting-Progressions)
#
# ## Introduction
#
# The **Traveling Salesman Problem (TSP)** is a well-known algorithmic problem in the field of computer science and operations research. It focuses on optimization. In this problem, a salesman is given a list of cities and must determine the shortest possible route that visits each city exactly once and returns to the origin city.
#
# This notebook implements two approaches to solve the TSP:
#
# 1. **Genetic Algorithm (GA):** An evolutionary algorithm inspired by natural selection, which iteratively evolves a population of candidate solutions.
# 2. **Greedy Algorithm:** A heuristic-based approach that builds a solution step-by-step, always choosing the locally optimal choice at each step.
#
# By comparing these two methods, we can analyze their effectiveness, efficiency, and applicability to different datasets.
#
# ## Importing Libraries
#
# We begin by importing the necessary libraries required for data manipulation, mathematical computations, geographic distance calculations, and logging. These libraries include:
#
# - `logging`: For logging informational and error messages.
# - `pandas`: For data manipulation and analysis.
# - `numpy`: For numerical computations.
# - `geopy`: Specifically, `geodesic` for calculating geodesic distances between coordinates.
# - `itertools`: For efficient looping, particularly the `combinations` function.
# - `csv`: For reading and writing CSV files.
# - `time`: For measuring execution time.
# - `matplotlib`: For plotting results.

# %%
import logging
import pandas as pd
import numpy as np
from geopy.distance import geodesic
from itertools import combinations
import csv  # For saving results
import time  # For measuring elapsed time
import matplotlib.pyplot as plt  # For plotting

# Configure logging
logging.basicConfig(level=logging.INFO)

# Set a seed for reproducibility
SEED = 42
rng = np.random.default_rng(np.random.PCG64(SEED))

# %% [markdown]
# ## Utility Functions
#
# This section encompasses a series of utility functions essential for setting up and running both the Genetic and Greedy algorithms. These functions handle tasks such as creating distance matrices, calculating tour costs, initializing populations, and performing selection, crossover, and mutation operations.
#
# ### Distance Matrix Creation
#
# The `create_distance_matrix` function computes a symmetric matrix representing the geodesic distances between each pair of cities. This matrix serves as the foundational data structure for evaluating tour costs in both algorithms.
#
# **Parameters:**
# - `cities` (`pd.DataFrame`): A DataFrame containing city information with columns `'name'`, `'lat'`, and `'lon'`.
#
# **Returns:**
# - `np.ndarray`: A symmetric matrix where the entry at position `(i, j)` represents the distance between city `i` and city `j` in kilometers.

# %%
def create_distance_matrix(cities):
    """
    Create a distance matrix for a list of cities based on geodesic distance.

    Parameters:
        cities (pd.DataFrame): DataFrame with columns 'name', 'lat', 'lon'.

    Returns:
        np.ndarray: A symmetric matrix where entry (i, j) is the distance between city i and city j.
    """
    dist_matrix = np.zeros((len(cities), len(cities)))
    for c1, c2 in combinations(cities.itertuples(index=True), 2):
        distance = geodesic((c1.lat, c1.lon), (c2.lat, c2.lon)).km
        dist_matrix[c1.Index, c2.Index] = distance
        dist_matrix[c2.Index, c1.Index] = distance
    return dist_matrix

# %% [markdown]
# ### TSP Cost Calculation
#
# The `tsp_cost` function calculates the total distance of a given TSP tour based on the distance matrix. It ensures that the tour is a cycle by checking if the first and last cities are the same.
#
# **Parameters:**
# - `tsp` (`list`): A list of integers representing the tour, where each integer is an index of a city.
# - `dist_matrix` (`np.ndarray`): The distance matrix for the cities.
#
# **Returns:**
# - `float`: The total cost (distance) of the tour in kilometers.

# %%
def tsp_cost(tsp, dist_matrix):
    """
    Calculate the total distance (cost) of a given TSP tour.

    Parameters:
        tsp (list): A list of integers representing a tour, where each integer is an index of a city.
        dist_matrix (np.ndarray): The distance matrix for the cities.

    Returns:
        float: The total cost (distance) of the tour.
    """
    if tsp[0] != tsp[-1]:  # Ensure the tour is a cycle
        tsp = tsp + [tsp[0]]
    tot_cost = sum(dist_matrix[tsp[i], tsp[i + 1]] for i in range(len(tsp) - 1))
    return tot_cost

# %% [markdown]
# ### Adaptive Population Size
#
# The `adaptive_population` function determines an optimal population size based on the number of cities.
#
# **Parameters:**
# - `cities_count` (`int`): The number of cities in the dataset.
#
# **Returns:**
# - `int`: An optimal population size.

# %%
def adaptive_population(cities_count):
    """
    Determine an adaptive population size based on the number of cities.

    Parameters:
        cities_count (int): The number of cities in the dataset.

    Returns:
        int: An optimal population size.
    """
    if cities_count < 50:
        return 100
    elif cities_count < 200:
        return 200
    else:
        return 300

# %% [markdown]
# ### Population Initialization
#
# The `initialize_population` function generates an initial population of random TSP tours. Each tour is a random permutation of city indices, ensuring diversity in the initial population.
#
# **Parameters:**
# - `cities_count` (`int`): The number of cities in the dataset.
# - `pop_size` (`int`): The number of tours to generate.
#
# **Returns:**
# - `list of lists`: A population of TSP tours. Each tour is a list of city indices representing a cycle (starts and ends at the same city).

# %%
def initialize_population(cities_count, pop_size):
    """
    Generate an initial population of random TSP tours.

    Parameters:
        cities_count (int): The number of cities in the dataset.
        pop_size (int): The number of tours to generate.

    Returns:
        list of lists: A population of TSP tours. Each tour is a list of city indices representing
                       a cycle (starts and ends at the same city).
    """
    population = []
    for _ in range(pop_size):
        tour = list(range(cities_count))
        rng.shuffle(tour)  # Use rng for reproducibility
        tour.append(tour[0])  # Ensure the tour is a cycle
        population.append(tour)
    return population

# %% [markdown]
# ### Selection Mechanism: Tournament Selection
#
# The `tournament_selection` function implements the tournament selection strategy, which selects the best individual out of a randomly chosen subset of the population. This method maintains selective pressure towards better solutions.
#
# **Parameters:**
# - `population` (`list of lists`): The population of tours.
# - `dist_matrix` (`np.ndarray`): The distance matrix for the cities.
# - `k` (`int`): The number of individuals to sample for the tournament. Default is 15.
#
# **Returns:**
# - `list`: The selected tour (winner of the tournament).

# %%
def tournament_selection(population, dist_matrix, k=15):
    """
    Select a tour from the population using tournament selection.

    Parameters:
        population (list of lists): The population of tours.
        dist_matrix (np.ndarray): The distance matrix for the cities.
        k (int): The number of individuals to sample for the tournament. Default is 15.

    Returns:
        list: The selected tour (winner of the tournament).
    """
    selected = rng.choice(population, k, replace=False)
    selected_sorted = sorted(selected, key=lambda tsp: tsp_cost(tsp, dist_matrix))
    return selected_sorted[0]

# %% [markdown]
# ### Crossover Mechanism: Order Crossover (OX)
#
# The `order_crossover` function performs Order Crossover (OX) between two parent tours to produce an offspring. This method preserves the relative order of cities, maintaining valid tours.
#
# **Parameters:**
# - `parent1` (`list`): The first parent tour.
# - `parent2` (`list`): The second parent tour.
#
# **Returns:**
# - `list`: The offspring tour generated by combining segments of the two parents.
#
# Ensures that the offspring is a cycle by setting the last element to match the first.

# %%
def order_crossover(parent1, parent2):
    """
    Perform order crossover (OX) between two parent tours to produce an offspring tour.

    Parameters:
        parent1 (list): The first parent tour.
        parent2 (list): The second parent tour.

    Returns:
        list: The offspring tour generated by combining segments of the two parents.
    """
    size = len(parent1) - 1  # Exclude the last city since it's a cycle
    start, end = sorted(rng.choice(range(size), 2, replace=False))
    child = [-1] * size
    child[start:end + 1] = parent1[start:end + 1]
    
    ptr = 0
    for city in parent2:
        if city not in child:
            while child[ptr] != -1:
                ptr += 1
            child[ptr] = city
    child.append(child[0])  # Ensure the child tour is a cycle
    return child

# %% [markdown]
# ### Mutation Mechanism: Inversion Mutation
#
# The `inversion_mutation` function applies inversion mutation to a TSP tour. It selects a random segment of the tour and reverses its order, introducing variability while maintaining valid tours.
#
# **Parameters:**
# - `tour` (`list`): The tour to mutate.
#
# **Returns:**
# - `list`: The mutated tour.
#
# Ensures the tour remains a cycle after mutation.

# %%
def inversion_mutation(tour):
    """
    Apply inversion mutation to a TSP tour.

    Parameters:
        tour (list): The tour to mutate.

    Returns:
        list: The mutated tour.

    Selects a random segment of the tour and reverses its order. Ensures the tour remains a cycle.
    """
    size = len(tour) - 1  # Exclude the last city since it's a cycle
    start, end = sorted(rng.choice(range(size), 2, replace=False))
    mutated_segment = list(reversed(tour[start:end + 1]))
    tour[start:end + 1] = mutated_segment
    if tour[-1] != tour[0]:  # Ensure the tour is a cycle
        tour[-1] = tour[0]
    return tour

# %% [markdown]
# ## Genetic Algorithm Implementation
#
# The Genetic Algorithm (GA) is an evolutionary algorithm inspired by natural selection. It iteratively evolves a population of candidate solutions towards better solutions. In the context of TSP, each individual in the population represents a possible tour.
#
# ### Key Components:
# - **Initialization**: Generate an initial population of random tours.
# - **Selection**: Select parent tours based on their fitness (tour cost).
# - **Crossover**: Combine parent tours to produce offspring.
# - **Mutation**: Introduce random variations to offspring tours.
# - **Elitism**: Preserve a subset of the best tours across generations.
# - **Termination**: Repeat the process for a predefined number of generations or until convergence.
#
# ### Genetic Algorithm Function

# %%
def ea_tsp(cities, pop_size, generations):
    """
    Solve the TSP using a genetic algorithm.

    Parameters:
        cities (pd.DataFrame): DataFrame containing city information.
        pop_size (int): The number of individuals (tours) in the population.
        generations (int): The number of generations to evolve the population.

    Returns:
        tuple: The best tour found, its associated cost, the generation when it was first found,
               and the cost progression over generations.
    """
    dist_matrix = create_distance_matrix(cities)
    population = initialize_population(len(cities), pop_size * 2)  # Increase initial population
    
    best_solution = min(population, key=lambda tsp: tsp_cost(tsp, dist_matrix))
    best_cost = tsp_cost(best_solution, dist_matrix)
    first_generation_ea = 0  # Initialize to 0 for the first generation
    cost_progression = [best_cost]  # To track cost over generations
    
    total_time = 0  # Total elapsed time
    start_time = time.time()  # Start time
    
    for generation in range(1, generations + 1):
        gen_start_time = time.time()
        
        new_population = []
        
        # Elitism: Keep the top 5% of the current generation
        elite_count = max(1, int(0.05 * pop_size))  # Ensure at least one elite
        elite_individuals = sorted(population, key=lambda tsp: tsp_cost(tsp, dist_matrix))[:elite_count]
        new_population.extend(elite_individuals)
        
        # Fill the rest of the population with crossover and mutation
        while len(new_population) < pop_size:
            # Tournament selection with higher pressure
            parent1 = tournament_selection(population, dist_matrix, k=10)
            parent2 = tournament_selection(population, dist_matrix, k=10)
            
            # Apply crossover with a higher probability
            if rng.random() < 0.9:
                child1 = order_crossover(parent1, parent2)
                child2 = order_crossover(parent2, parent1)
            else:
                child1, child2 = parent1.copy(), parent2.copy()
            
            # Apply mutation with a dynamically decreasing probability
            mutation_rate = max(0.01, 0.1 - (0.1 * generation / generations))
            if rng.random() < mutation_rate:
                child1 = inversion_mutation(child1)
            if rng.random() < mutation_rate:
                child2 = inversion_mutation(child2)
            
            new_population.extend([child1, child2])
        
        # Trim excess individuals if population exceeds pop_size
        population = new_population[:pop_size]
        
        # Update best solution
        current_best = min(population, key=lambda tsp: tsp_cost(tsp, dist_matrix))
        current_cost = tsp_cost(current_best, dist_matrix)
        cost_progression.append(current_cost)
        
        if current_cost < best_cost:
            best_solution, best_cost = current_best, current_cost
            first_generation_ea = generation  # Update the first generation when new best is found
            logging.info(f"Generation {generation}: New best cost = {best_cost:.2f} km")
        
        # Optional: Log progress every 50 generations
        if generation % 50 == 0:
            elapsed_time = time.time() - start_time
            average_time_per_gen = elapsed_time / generation
            remaining_gens = generations - generation
            estimated_remaining_time = average_time_per_gen * remaining_gens
            logging.info(f"Generation {generation}: Current best cost = {best_cost:.2f} km")
            logging.info(f"Elapsed Time: {elapsed_time/60:.2f} minutes | Estimated Remaining Time: {estimated_remaining_time/60:.2f} minutes")

    total_time = time.time() - start_time
    logging.info(f"Best solution found with cost = {best_cost:.2f} km in {total_time:.2f} seconds at generation {first_generation_ea}")
    return best_solution, best_cost, first_generation_ea, cost_progression

# %% [markdown]
# ### Running the Genetic Algorithm on Multiple Datasets
#
# The `run_multiple_datasets_ea` function executes the Genetic Algorithm on multiple city datasets and records the results in a CSV file. This allows for comparative analysis across different geographical regions.
#
# **Parameters:**
# - `filenames` (`list of str`): List of file paths for the city datasets.
# - `output_file` (`str`): Path to the output CSV file.
# - `generations` (`int`): The number of generations to evolve the population for each dataset.
#
# **Functionality:**
# - Loads each dataset.
# - Determines an adaptive population size based on the number of cities.
# - Runs the Genetic Algorithm.
# - Records the best tour and its cost.
# - Handles exceptions and logs errors if any occur during processing.

# %%
def run_multiple_datasets_ea(filenames, output_file, generations=25):
    """
    Run the genetic algorithm on multiple datasets and save the results to a CSV file.

    Parameters:
        filenames (list of str): List of file paths for the city datasets.
        output_file (str): Path to the output CSV file.
        generations (int): The number of generations to evolve the population for each dataset.

    Returns:
        dict: Progression data for plotting.
    """
    results = []
    ea_progressions = {}  # To store progression data for plotting
    
    for filename in filenames:
        try:
            # Load cities data
            cities = pd.read_csv(filename, header=None, names=['name', 'lat', 'lon'])
            cities_count = len(cities)
            population_size = adaptive_population(cities_count)
            
            logging.info(f"Processing {filename} with {cities_count} cities. Population size set to {population_size}.")
            
            # Run genetic algorithm
            best_tour, best_cost, first_generation_ea, cost_progression = ea_tsp(cities, pop_size=population_size, generations=generations)
            
            # Append results
            results.append({
                'filename': filename,
                'num_cities': cities_count,
                'best_cost_km': round(best_cost, 2),
                'first_generation_ea': first_generation_ea,
                'best_tour': best_tour
            })
            
            # Store progression data
            ea_progressions[filename] = cost_progression
            
            logging.info(f"Completed TSP for {filename}. Best cost: {best_cost:.2f} km at generation {first_generation_ea}")
        
        except Exception as e:
            logging.error(f"An error occurred while processing {filename}: {e}")
            results.append({
                'filename': filename,
                'num_cities': len(cities) if 'cities' in locals() else 'N/A',
                'best_cost_km': 'Error',
                'first_generation_ea': 'Error',
                'best_tour': 'Error'
            })
    
    # Save results to CSV
    try:
        with open(output_file, mode='w', newline='') as file:
            fieldnames = ['filename', 'num_cities', 'best_cost_km', 'first_generation_ea', 'best_tour']
            writer = csv.DictWriter(file, fieldnames=fieldnames)
            writer.writeheader()
            for result in results:
                writer.writerow(result)
        logging.info(f"EA Results successfully saved to {output_file}")
    except Exception as e:
        logging.error(f"Failed to save EA results to {output_file}: {e}")
    
    return ea_progressions  # Return progression data for plotting

# %% [markdown]
# ## Greedy Algorithm Implementation
#
# The Greedy Algorithm provides a heuristic-based solution to the TSP by iteratively selecting the nearest unvisited city. While it doesn't guarantee an optimal solution, it offers a quick approximation suitable for larger datasets.
#
# ### Greedy Algorithm Function

# %%
def greedy_tsp(cities):
    """
    Solve the TSP using a greedy approach.

    Parameters:
        cities (pd.DataFrame): DataFrame with columns 'name', 'lat', 'lon'.

    Returns:
        tuple: The best tour found, its associated cost, the step when the tour was completed,
               and the cost progression over steps.
    """
    dist_matrix = create_distance_matrix(cities)
    num_cities = len(cities)
    
    # Start from the first city
    tour = [0]
    visited = set(tour)
    cost_progression = []  # To track cost after each step
    
    while len(tour) < num_cities:
        last = tour[-1]
        # Find the nearest unvisited city
        next_city = min(
            (i for i in range(num_cities) if i not in visited),
            key=lambda x: dist_matrix[last, x]
        )
        tour.append(next_city)
        visited.add(next_city)
        current_cost = tsp_cost(tour, dist_matrix)
        cost_progression.append(current_cost)
        logging.debug(
            f"step: {cities.at[last,'name']} -> {cities.at[next_city,'name']} ({dist_matrix[last, next_city]:.2f}km), Current Cost: {current_cost:.2f}km"
        )
    
    # Complete the tour by returning to the starting city
    tour.append(tour[0])
    total_cost = tsp_cost(tour, dist_matrix)
    cost_progression.append(total_cost)
    logging.debug(
        f"step: {cities.at[tour[-2],'name']} -> {cities.at[tour[0],'name']} ({dist_matrix[tour[-2], tour[0]]:.2f}km), Total Cost: {total_cost:.2f}km"
    )
    
    logging.info(f"result: Found a path of {len(tour)-1} steps, total length {total_cost:.2f}km")
    first_step_greedy = len(tour) - 1  # The final step completes the tour
    
    return tour, total_cost, first_step_greedy, cost_progression

# %% [markdown]
# ### Running the Greedy Algorithm on Multiple Datasets
#
# The `run_multiple_datasets_greedy` function executes the Greedy Algorithm on multiple city datasets and records the results in a CSV file. This facilitates a performance comparison between the Genetic and Greedy approaches.
#
# **Parameters:**
# - `filenames` (`list of str`): List of file paths for the city datasets.
# - `output_file` (`str`): Path to the output CSV file.
#
# **Functionality:**
# - Loads each dataset.
# - Runs the Greedy Algorithm.
# - Records the best tour and its cost.
# - Handles exceptions and logs errors if any occur during processing.

# %%
def run_multiple_datasets_greedy(filenames, output_file):
    """
    Run the greedy TSP algorithm on multiple datasets and save the results to a CSV file.

    Parameters:
        filenames (list of str): List of file paths for the city datasets.
        output_file (str): Path to the output CSV file.

    Returns:
        dict: Progression data for plotting.
    """
    results = []
    greedy_progressions = {}  # To store progression data for plotting
    
    for filename in filenames:
        try:
            # Load cities data
            cities = pd.read_csv(filename, header=None, names=['name', 'lat', 'lon'])
            cities_count = len(cities)
            
            logging.info(f"Processing {filename} with {cities_count} cities using greedy algorithm.")
            
            # Run greedy TSP
            best_tour, best_cost, first_step_greedy, cost_progression = greedy_tsp(cities)
            
            # Append results
            results.append({
                'filename': filename,
                'num_cities': cities_count,
                'best_cost_km': round(best_cost, 2),
                'first_step_greedy': first_step_greedy,
                'best_tour': best_tour
            })
            
            # Store progression data
            greedy_progressions[filename] = cost_progression
            
            logging.info(f"Completed TSP for {filename} using greedy approach. Best cost: {best_cost:.2f} km at step {first_step_greedy}")
        
        except Exception as e:
            logging.error(f"An error occurred while processing {filename} with greedy algorithm: {e}")
            results.append({
                'filename': filename,
                'num_cities': len(cities) if 'cities' in locals() else 'N/A',
                'best_cost_km': 'Error',
                'first_step_greedy': 'Error',
                'best_tour': 'Error'
            })
    
    # Save results to CSV
    try:
        with open(output_file, mode='w', newline='') as file:
            fieldnames = ['filename', 'num_cities', 'best_cost_km', 'first_step_greedy', 'best_tour']
            writer = csv.DictWriter(file, fieldnames=fieldnames)
            writer.writeheader()
            for result in results:
                writer.writerow(result)
        logging.info(f"Greedy Results successfully saved to {output_file}")
    except Exception as e:
        logging.error(f"Failed to save Greedy results to {output_file}: {e}")
    
    return greedy_progressions  # Return progression data for plotting

# %% [markdown]
# ## Running Experiments
#
# In this section, we define the datasets to be analyzed and execute both the Genetic and Greedy algorithms on these datasets. The results are saved to respective CSV files for further analysis.
#
# **Datasets Included:**
# - `italy.csv`
# - `vanuatu.csv`
# - `russia.csv`
# - `us.csv`
# - `china.csv`
#
# **Note:** Ensure that the datasets are located in the specified `cities/` directory or adjust the file paths accordingly.

# %%
# List of files to analyze and output files
filenames = [
    "cities/italy.csv",
    "cities/vanuatu.csv",
    "cities/russia.csv",
    "cities/us.csv",
    "cities/china.csv"
]

# Execute the calculations for EA
output_file_ea = "tsp_results_ea.csv"
ea_progressions = run_multiple_datasets_ea(filenames, output_file_ea, generations=1000)
print(f"EA Results saved to {output_file_ea}")

# Execute the calculations for Greedy
output_file_greedy = "tsp_results_greedy.csv"
greedy_progressions = run_multiple_datasets_greedy(filenames, output_file_greedy)
print(f"Greedy Results saved to {output_file_greedy}")
# Out:
# INFO:root:Processing cities/italy.csv with 46 cities. Population size set to 100.
# INFO:root:Generation 1: New best cost = 14890.41 km
# INFO:root:Generation 2: New best cost = 14642.97 km
# INFO:root:Generation 3: New best cost = 13659.68 km
# INFO:root:Generation 4: New best cost = 13454.59 km
# INFO:root:Generation 5: New best cost = 13045.51 km
# INFO:root:Generation 6: New best cost = 12822.15 km
# INFO:root:Generation 7: New best cost = 12427.94 km
# INFO:root:Generation 9: New best cost = 11872.47 km
# INFO:root:Generation 10: New best cost = 11654.84 km
# INFO:root:Generation 11: New best cost = 11304.49 km
# INFO:root:Generation 12: New best cost = 11273.46 km
# INFO:root:Generation 13: New best cost = 10852.27 km
# INFO:root:Generation 14: New best cost = 10158.20 km
# INFO:root:Generation 15: New best cost = 9960.86 km
# INFO:root:Generation 16: New best cost = 9736.65 km
# INFO:root:Generation 18: New best cost = 9691.17 km
# INFO:root:Generation 19: New best cost = 9419.34 km
# INFO:root:Generation 20: New best cost = 9352.18 km
# INFO:root:Generation 21: New best cost = 9182.71 km
# INFO:root:Generation 22: New best cost = 8996.41 km
# INFO:root:Generation 23: New best cost = 8957.35 km
# INFO:root:Generation 24: New best cost = 8723.04 km
# INFO:root:Generation 25: New best cost = 8501.45 km
# INFO:root:Generation 26: New best cost = 8351.50 km
# INFO:root:Generation 27: New best cost = 8003.83 km
# INFO:root:Generation 30: New best cost = 7797.58 km
# INFO:root:Generation 31: New best cost = 7714.13 km
# INFO:root:Generation 33: New best cost = 7684.91 km
# INFO:root:Generation 35: New best cost = 7522.86 km
# INFO:root:Generation 37: New best cost = 7364.87 km
# INFO:root:Generation 38: New best cost = 7356.64 km
# INFO:root:Generation 39: New best cost = 7288.74 km
# INFO:root:Generation 40: New best cost = 7031.33 km
# INFO:root:Generation 41: New best cost = 6995.75 km
# INFO:root:Generation 42: New best cost = 6928.91 km
# INFO:root:Generation 43: New best cost = 6842.25 km
# INFO:root:Generation 44: New best cost = 6841.13 km
# INFO:root:Generation 45: New best cost = 6694.52 km
# INFO:root:Generation 46: New best cost = 6677.10 km
# INFO:root:Generation 47: New best cost = 6600.72 km
# INFO:root:Generation 49: New best cost = 6576.25 km
# INFO:root:Generation 50: Current best cost = 6576.25 km
# INFO:root:Elapsed Time: 0.04 minutes | Estimated Remaining Time: 0.81 minutes
# INFO:root:Generation 51: New best cost = 6574.02 km
# INFO:root:Generation 53: New best cost = 6457.43 km
# INFO:root:Generation 55: New best cost = 6455.43 km
# INFO:root:Generation 60: New best cost = 6444.40 km
# INFO:root:Generation 62: New best cost = 6435.41 km
# INFO:root:Generation 63: New best cost = 6147.14 km
# INFO:root:Generation 65: New best cost = 6138.15 km
# INFO:root:Generation 66: New best cost = 6101.94 km
# INFO:root:Generation 67: New best cost = 6085.29 km
# INFO:root:Generation 73: New best cost = 6070.16 km
# INFO:root:Generation 75: New best cost = 5929.12 km
# INFO:root:Generation 77: New best cost = 5777.34 km
# INFO:root:Generation 79: New best cost = 5741.57 km
# INFO:root:Generation 80: New best cost = 5733.49 km
# INFO:root:Generation 89: New best cost = 5695.25 km
# INFO:root:Generation 92: New best cost = 5678.77 km
# INFO:root:Generation 94: New best cost = 5576.88 km
# INFO:root:Generation 100: Current best cost = 5576.88 km
# INFO:root:Elapsed Time: 0.08 minutes | Estimated Remaining Time: 0.76 minutes
# INFO:root:Generation 104: New best cost = 5181.45 km
# INFO:root:Generation 106: New best cost = 5129.98 km
# INFO:root:Generation 112: New best cost = 5024.02 km
# INFO:root:Generation 116: New best cost = 4991.87 km
# INFO:root:Generation 121: New best cost = 4952.73 km
# INFO:root:Generation 123: New best cost = 4923.99 km
# INFO:root:Generation 141: New best cost = 4913.95 km
# INFO:root:Generation 142: New best cost = 4843.41 km
# INFO:root:Generation 150: New best cost = 4835.28 km
# INFO:root:Generation 150: Current best cost = 4835.28 km
# INFO:root:Elapsed Time: 0.13 minutes | Estimated Remaining Time: 0.71 minutes
# INFO:root:Generation 152: New best cost = 4833.56 km
# INFO:root:Generation 181: New best cost = 4820.59 km
# INFO:root:Generation 199: New best cost = 4798.13 km
# INFO:root:Generation 200: New best cost = 4770.18 km
# INFO:root:Generation 200: Current best cost = 4770.18 km
# INFO:root:Elapsed Time: 0.17 minutes | Estimated Remaining Time: 0.68 minutes
# INFO:root:Generation 201: New best cost = 4709.82 km
# INFO:root:Generation 202: New best cost = 4691.79 km
# INFO:root:Generation 213: New best cost = 4649.33 km
# INFO:root:Generation 225: New best cost = 4645.68 km
# INFO:root:Generation 233: New best cost = 4622.10 km
# INFO:root:Generation 250: Current best cost = 4622.10 km
# INFO:root:Elapsed Time: 0.21 minutes | Estimated Remaining Time: 0.63 minutes
# INFO:root:Generation 257: New best cost = 4618.68 km
# INFO:root:Generation 259: New best cost = 4441.45 km
# INFO:root:Generation 282: New best cost = 4431.07 km
# INFO:root:Generation 300: Current best cost = 4431.07 km
# INFO:root:Elapsed Time: 0.25 minutes | Estimated Remaining Time: 0.59 minutes
# INFO:root:Generation 350: Current best cost = 4431.07 km
# INFO:root:Elapsed Time: 0.30 minutes | Estimated Remaining Time: 0.56 minutes
# INFO:root:Generation 400: Current best cost = 4431.07 km
# INFO:root:Elapsed Time: 0.34 minutes | Estimated Remaining Time: 0.51 minutes
# INFO:root:Generation 450: Current best cost = 4431.07 km
# INFO:root:Elapsed Time: 0.38 minutes | Estimated Remaining Time: 0.47 minutes
# INFO:root:Generation 500: Current best cost = 4431.07 km
# INFO:root:Elapsed Time: 0.42 minutes | Estimated Remaining Time: 0.42 minutes
# INFO:root:Generation 514: New best cost = 4339.72 km
# INFO:root:Generation 534: New best cost = 4324.42 km
# INFO:root:Generation 535: New best cost = 4319.70 km
# INFO:root:Generation 550: Current best cost = 4319.70 km
# INFO:root:Elapsed Time: 0.46 minutes | Estimated Remaining Time: 0.38 minutes
# INFO:root:Generation 600: Current best cost = 4319.70 km
# INFO:root:Elapsed Time: 0.51 minutes | Estimated Remaining Time: 0.34 minutes
# INFO:root:Generation 650: Current best cost = 4319.70 km
# INFO:root:Elapsed Time: 0.55 minutes | Estimated Remaining Time: 0.29 minutes
# INFO:root:Generation 700: Current best cost = 4319.70 km
# INFO:root:Elapsed Time: 0.59 minutes | Estimated Remaining Time: 0.25 minutes
# INFO:root:Generation 750: Current best cost = 4319.70 km
# INFO:root:Elapsed Time: 0.63 minutes | Estimated Remaining Time: 0.21 minutes
# INFO:root:Generation 800: Current best cost = 4319.70 km
# INFO:root:Elapsed Time: 0.67 minutes | Estimated Remaining Time: 0.17 minutes
# INFO:root:Generation 850: Current best cost = 4319.70 km
# INFO:root:Elapsed Time: 0.71 minutes | Estimated Remaining Time: 0.12 minutes
# INFO:root:Generation 900: Current best cost = 4319.70 km
# INFO:root:Elapsed Time: 0.75 minutes | Estimated Remaining Time: 0.08 minutes
# INFO:root:Generation 950: Current best cost = 4319.70 km
# INFO:root:Elapsed Time: 0.79 minutes | Estimated Remaining Time: 0.04 minutes
# INFO:root:Generation 1000: Current best cost = 4319.70 km
# INFO:root:Elapsed Time: 0.83 minutes | Estimated Remaining Time: 0.00 minutes
# INFO:root:Best solution found with cost = 4319.70 km in 49.66 seconds at generation 535
# INFO:root:Completed TSP for cities/italy.csv. Best cost: 4319.70 km at generation 535
# INFO:root:Processing cities/vanuatu.csv with 8 cities. Population size set to 100.
# INFO:root:Generation 3: New best cost = 1345.54 km
# INFO:root:Generation 50: Current best cost = 1345.54 km
# INFO:root:Elapsed Time: 0.01 minutes | Estimated Remaining Time: 0.20 minutes
# INFO:root:Generation 100: Current best cost = 1345.54 km
# INFO:root:Elapsed Time: 0.02 minutes | Estimated Remaining Time: 0.19 minutes
# INFO:root:Generation 150: Current best cost = 1345.54 km
# INFO:root:Elapsed Time: 0.03 minutes | Estimated Remaining Time: 0.18 minutes
# INFO:root:Generation 200: Current best cost = 1345.54 km
# INFO:root:Elapsed Time: 0.04 minutes | Estimated Remaining Time: 0.17 minutes
# INFO:root:Generation 250: Current best cost = 1345.54 km
# INFO:root:Elapsed Time: 0.05 minutes | Estimated Remaining Time: 0.16 minutes
# INFO:root:Generation 300: Current best cost = 1345.54 km
# INFO:root:Elapsed Time: 0.06 minutes | Estimated Remaining Time: 0.15 minutes
# INFO:root:Generation 350: Current best cost = 1345.54 km
# INFO:root:Elapsed Time: 0.07 minutes | Estimated Remaining Time: 0.14 minutes
# INFO:root:Generation 400: Current best cost = 1345.54 km
# INFO:root:Elapsed Time: 0.08 minutes | Estimated Remaining Time: 0.12 minutes
# INFO:root:Generation 450: Current best cost = 1345.54 km
# INFO:root:Elapsed Time: 0.09 minutes | Estimated Remaining Time: 0.11 minutes
# INFO:root:Generation 500: Current best cost = 1345.54 km
# INFO:root:Elapsed Time: 0.10 minutes | Estimated Remaining Time: 0.10 minutes
# INFO:root:Generation 550: Current best cost = 1345.54 km
# INFO:root:Elapsed Time: 0.11 minutes | Estimated Remaining Time: 0.09 minutes
# INFO:root:Generation 600: Current best cost = 1345.54 km
# INFO:root:Elapsed Time: 0.12 minutes | Estimated Remaining Time: 0.08 minutes
# INFO:root:Generation 650: Current best cost = 1345.54 km
# INFO:root:Elapsed Time: 0.14 minutes | Estimated Remaining Time: 0.07 minutes
# INFO:root:Generation 700: Current best cost = 1345.54 km
# INFO:root:Elapsed Time: 0.15 minutes | Estimated Remaining Time: 0.06 minutes
# INFO:root:Generation 750: Current best cost = 1345.54 km
# INFO:root:Elapsed Time: 0.16 minutes | Estimated Remaining Time: 0.05 minutes
# INFO:root:Generation 800: Current best cost = 1345.54 km
# INFO:root:Elapsed Time: 0.17 minutes | Estimated Remaining Time: 0.04 minutes
# INFO:root:Generation 850: Current best cost = 1345.54 km
# INFO:root:Elapsed Time: 0.18 minutes | Estimated Remaining Time: 0.03 minutes
# INFO:root:Generation 900: Current best cost = 1345.54 km
# INFO:root:Elapsed Time: 0.19 minutes | Estimated Remaining Time: 0.02 minutes
# INFO:root:Generation 950: Current best cost = 1345.54 km
# INFO:root:Elapsed Time: 0.20 minutes | Estimated Remaining Time: 0.01 minutes
# INFO:root:Generation 1000: Current best cost = 1345.54 km
# INFO:root:Elapsed Time: 0.21 minutes | Estimated Remaining Time: 0.00 minutes
# INFO:root:Best solution found with cost = 1345.54 km in 12.47 seconds at generation 3
# INFO:root:Completed TSP for cities/vanuatu.csv. Best cost: 1345.54 km at generation 3
# INFO:root:Processing cities/russia.csv with 167 cities. Population size set to 200.
# INFO:root:Generation 1: New best cost = 282450.72 km
# INFO:root:Generation 2: New best cost = 278080.73 km
# INFO:root:Generation 3: New best cost = 268420.20 km
# INFO:root:Generation 4: New best cost = 264159.64 km
# INFO:root:Generation 5: New best cost = 255761.79 km
# INFO:root:Generation 6: New best cost = 255087.63 km
# INFO:root:Generation 7: New best cost = 248949.93 km
# INFO:root:Generation 8: New best cost = 241599.90 km
# INFO:root:Generation 9: New best cost = 233434.45 km
# INFO:root:Generation 10: New best cost = 228253.15 km
# INFO:root:Generation 11: New best cost = 227186.86 km
# INFO:root:Generation 12: New best cost = 218175.93 km
# INFO:root:Generation 13: New best cost = 216597.95 km
# INFO:root:Generation 14: New best cost = 212679.18 km
# INFO:root:Generation 15: New best cost = 210443.18 km
# INFO:root:Generation 16: New best cost = 206333.80 km
# INFO:root:Generation 17: New best cost = 203004.93 km
# INFO:root:Generation 18: New best cost = 201891.34 km
# INFO:root:Generation 19: New best cost = 197820.18 km
# INFO:root:Generation 20: New best cost = 194832.94 km
# INFO:root:Generation 21: New best cost = 191364.32 km
# INFO:root:Generation 23: New best cost = 188627.62 km
# INFO:root:Generation 24: New best cost = 185745.94 km
# INFO:root:Generation 25: New best cost = 183351.96 km
# INFO:root:Generation 26: New best cost = 180693.08 km
# INFO:root:Generation 28: New best cost = 178656.85 km
# INFO:root:Generation 29: New best cost = 176303.77 km
# INFO:root:Generation 30: New best cost = 173154.53 km
# INFO:root:Generation 31: New best cost = 172535.77 km
# INFO:root:Generation 32: New best cost = 171699.90 km
# INFO:root:Generation 33: New best cost = 170211.29 km
# INFO:root:Generation 34: New best cost = 166510.02 km
# INFO:root:Generation 36: New best cost = 165136.85 km
# INFO:root:Generation 37: New best cost = 163632.97 km
# INFO:root:Generation 38: New best cost = 163033.11 km
# INFO:root:Generation 39: New best cost = 161901.62 km
# INFO:root:Generation 40: New best cost = 158719.08 km
# INFO:root:Generation 41: New best cost = 157895.91 km
# INFO:root:Generation 42: New best cost = 157873.68 km
# INFO:root:Generation 43: New best cost = 157445.31 km
# INFO:root:Generation 44: New best cost = 155547.72 km
# INFO:root:Generation 45: New best cost = 155188.60 km
# INFO:root:Generation 46: New best cost = 153327.43 km
# INFO:root:Generation 47: New best cost = 152875.35 km
# INFO:root:Generation 48: New best cost = 151136.83 km
# INFO:root:Generation 49: New best cost = 150443.73 km
# INFO:root:Generation 50: New best cost = 149635.83 km
# INFO:root:Generation 50: Current best cost = 149635.83 km
# INFO:root:Elapsed Time: 0.45 minutes | Estimated Remaining Time: 8.61 minutes
# INFO:root:Generation 51: New best cost = 148749.12 km
# INFO:root:Generation 52: New best cost = 147885.02 km
# INFO:root:Generation 53: New best cost = 145935.31 km
# INFO:root:Generation 54: New best cost = 144751.51 km
# INFO:root:Generation 55: New best cost = 142992.12 km
# INFO:root:Generation 56: New best cost = 141173.12 km
# INFO:root:Generation 58: New best cost = 139696.84 km
# INFO:root:Generation 59: New best cost = 138918.75 km
# INFO:root:Generation 60: New best cost = 136658.80 km
# INFO:root:Generation 61: New best cost = 135465.25 km
# INFO:root:Generation 62: New best cost = 133205.30 km
# INFO:root:Generation 63: New best cost = 132536.53 km
# INFO:root:Generation 64: New best cost = 131948.43 km
# INFO:root:Generation 65: New best cost = 131230.31 km
# INFO:root:Generation 66: New best cost = 130318.80 km
# INFO:root:Generation 69: New best cost = 127997.71 km
# INFO:root:Generation 70: New best cost = 127948.22 km
# INFO:root:Generation 72: New best cost = 127036.14 km
# INFO:root:Generation 73: New best cost = 126427.96 km
# INFO:root:Generation 74: New best cost = 126308.37 km
# INFO:root:Generation 75: New best cost = 125574.64 km
# INFO:root:Generation 76: New best cost = 124658.95 km
# INFO:root:Generation 77: New best cost = 124596.81 km
# INFO:root:Generation 78: New best cost = 123308.17 km
# INFO:root:Generation 80: New best cost = 123014.52 km
# INFO:root:Generation 81: New best cost = 122275.68 km
# INFO:root:Generation 82: New best cost = 121734.48 km
# INFO:root:Generation 84: New best cost = 121574.83 km
# INFO:root:Generation 85: New best cost = 119758.53 km
# INFO:root:Generation 86: New best cost = 118523.39 km
# INFO:root:Generation 88: New best cost = 115665.43 km
# INFO:root:Generation 89: New best cost = 115640.23 km
# INFO:root:Generation 90: New best cost = 115043.75 km
# INFO:root:Generation 91: New best cost = 114710.59 km
# INFO:root:Generation 92: New best cost = 113239.97 km
# INFO:root:Generation 93: New best cost = 113225.70 km
# INFO:root:Generation 94: New best cost = 112783.35 km
# INFO:root:Generation 95: New best cost = 112435.30 km
# INFO:root:Generation 96: New best cost = 110493.96 km
# INFO:root:Generation 97: New best cost = 109689.29 km
# INFO:root:Generation 98: New best cost = 108946.57 km
# INFO:root:Generation 99: New best cost = 108526.51 km
# INFO:root:Generation 100: New best cost = 108493.23 km
# INFO:root:Generation 100: Current best cost = 108493.23 km
# INFO:root:Elapsed Time: 0.91 minutes | Estimated Remaining Time: 8.15 minutes
# INFO:root:Generation 101: New best cost = 108011.25 km
# INFO:root:Generation 102: New best cost = 107893.20 km
# INFO:root:Generation 103: New best cost = 107377.94 km
# INFO:root:Generation 104: New best cost = 106474.63 km
# INFO:root:Generation 105: New best cost = 105841.33 km
# INFO:root:Generation 106: New best cost = 101898.21 km
# INFO:root:Generation 107: New best cost = 101704.61 km
# INFO:root:Generation 108: New best cost = 101328.14 km
# INFO:root:Generation 109: New best cost = 100829.38 km
# INFO:root:Generation 110: New best cost = 100259.31 km
# INFO:root:Generation 111: New best cost = 99828.49 km
# INFO:root:Generation 113: New best cost = 99816.10 km
# INFO:root:Generation 114: New best cost = 99018.82 km
# INFO:root:Generation 115: New best cost = 98157.46 km
# INFO:root:Generation 116: New best cost = 97719.79 km
# INFO:root:Generation 117: New best cost = 96922.52 km
# INFO:root:Generation 118: New best cost = 96717.99 km
# INFO:root:Generation 119: New best cost = 95380.34 km
# INFO:root:Generation 120: New best cost = 94145.39 km
# INFO:root:Generation 121: New best cost = 93444.63 km
# INFO:root:Generation 123: New best cost = 93128.03 km
# INFO:root:Generation 125: New best cost = 93007.86 km
# INFO:root:Generation 127: New best cost = 92514.87 km
# INFO:root:Generation 128: New best cost = 92188.63 km
# INFO:root:Generation 129: New best cost = 91929.11 km
# INFO:root:Generation 130: New best cost = 91623.29 km
# INFO:root:Generation 131: New best cost = 91476.58 km
# INFO:root:Generation 132: New best cost = 91304.22 km
# INFO:root:Generation 134: New best cost = 91276.56 km
# INFO:root:Generation 135: New best cost = 91233.99 km
# INFO:root:Generation 137: New best cost = 89936.40 km
# INFO:root:Generation 138: New best cost = 89797.90 km
# INFO:root:Generation 139: New best cost = 89298.35 km
# INFO:root:Generation 140: New best cost = 88337.65 km
# INFO:root:Generation 143: New best cost = 87554.23 km
# INFO:root:Generation 146: New best cost = 87099.89 km
# INFO:root:Generation 148: New best cost = 86887.37 km
# INFO:root:Generation 149: New best cost = 86878.53 km
# INFO:root:Generation 150: New best cost = 86654.10 km
# INFO:root:Generation 150: Current best cost = 86654.10 km
# INFO:root:Elapsed Time: 1.36 minutes | Estimated Remaining Time: 7.69 minutes
# INFO:root:Generation 151: New best cost = 86581.53 km
# INFO:root:Generation 152: New best cost = 86442.08 km
# INFO:root:Generation 153: New best cost = 85818.65 km
# INFO:root:Generation 155: New best cost = 85432.37 km
# INFO:root:Generation 156: New best cost = 85184.94 km
# INFO:root:Generation 157: New best cost = 84972.36 km
# INFO:root:Generation 158: New best cost = 84410.87 km
# INFO:root:Generation 159: New best cost = 84065.82 km
# INFO:root:Generation 160: New best cost = 83967.98 km
# INFO:root:Generation 162: New best cost = 83870.25 km
# INFO:root:Generation 163: New best cost = 82824.68 km
# INFO:root:Generation 164: New best cost = 82752.25 km
# INFO:root:Generation 165: New best cost = 81982.05 km
# INFO:root:Generation 167: New best cost = 81884.16 km
# INFO:root:Generation 168: New best cost = 81862.70 km
# INFO:root:Generation 169: New best cost = 80394.42 km
# INFO:root:Generation 171: New best cost = 79803.50 km
# INFO:root:Generation 172: New best cost = 79766.05 km
# INFO:root:Generation 173: New best cost = 79630.19 km
# INFO:root:Generation 174: New best cost = 79471.27 km
# INFO:root:Generation 175: New best cost = 79300.50 km
# INFO:root:Generation 176: New best cost = 79139.87 km
# INFO:root:Generation 177: New best cost = 78996.08 km
# INFO:root:Generation 178: New best cost = 78463.26 km
# INFO:root:Generation 179: New best cost = 78373.59 km
# INFO:root:Generation 180: New best cost = 78209.69 km
# INFO:root:Generation 181: New best cost = 77915.88 km
# INFO:root:Generation 182: New best cost = 77779.13 km
# INFO:root:Generation 183: New best cost = 77551.55 km
# INFO:root:Generation 184: New best cost = 77437.54 km
# INFO:root:Generation 185: New best cost = 77347.70 km
# INFO:root:Generation 186: New best cost = 77125.91 km
# INFO:root:Generation 188: New best cost = 76864.23 km
# INFO:root:Generation 189: New best cost = 76805.79 km
# INFO:root:Generation 190: New best cost = 76773.67 km
# INFO:root:Generation 191: New best cost = 76736.90 km
# INFO:root:Generation 192: New best cost = 76572.77 km
# INFO:root:Generation 193: New best cost = 76535.99 km
# INFO:root:Generation 194: New best cost = 76065.68 km
# INFO:root:Generation 195: New best cost = 75896.89 km
# INFO:root:Generation 196: New best cost = 75864.78 km
# INFO:root:Generation 197: New best cost = 75723.14 km
# INFO:root:Generation 198: New best cost = 75432.62 km
# INFO:root:Generation 200: New best cost = 75360.22 km
# INFO:root:Generation 200: Current best cost = 75360.22 km
# INFO:root:Elapsed Time: 1.81 minutes | Estimated Remaining Time: 7.25 minutes
# INFO:root:Generation 201: New best cost = 75355.01 km
# INFO:root:Generation 202: New best cost = 75103.36 km
# INFO:root:Generation 205: New best cost = 75009.67 km
# INFO:root:Generation 206: New best cost = 74013.49 km
# INFO:root:Generation 208: New best cost = 73927.07 km
# INFO:root:Generation 209: New best cost = 73376.87 km
# INFO:root:Generation 211: New best cost = 73270.53 km
# INFO:root:Generation 212: New best cost = 72919.48 km
# INFO:root:Generation 213: New best cost = 72875.85 km
# INFO:root:Generation 214: New best cost = 72521.38 km
# INFO:root:Generation 216: New best cost = 72152.18 km
# INFO:root:Generation 217: New best cost = 71884.59 km
# INFO:root:Generation 218: New best cost = 71822.73 km
# INFO:root:Generation 219: New best cost = 71595.77 km
# INFO:root:Generation 220: New best cost = 71445.59 km
# INFO:root:Generation 222: New best cost = 71302.07 km
# INFO:root:Generation 224: New best cost = 71063.05 km
# INFO:root:Generation 225: New best cost = 70599.40 km
# INFO:root:Generation 229: New best cost = 68500.85 km
# INFO:root:Generation 233: New best cost = 68477.93 km
# INFO:root:Generation 234: New best cost = 68407.02 km
# INFO:root:Generation 235: New best cost = 68389.02 km
# INFO:root:Generation 236: New best cost = 68107.57 km
# INFO:root:Generation 237: New best cost = 68018.65 km
# INFO:root:Generation 238: New best cost = 67010.66 km
# INFO:root:Generation 239: New best cost = 66734.13 km
# INFO:root:Generation 241: New best cost = 66725.55 km
# INFO:root:Generation 242: New best cost = 66574.74 km
# INFO:root:Generation 243: New best cost = 66317.11 km
# INFO:root:Generation 245: New best cost = 65995.31 km
# INFO:root:Generation 247: New best cost = 65830.72 km
# INFO:root:Generation 249: New best cost = 65792.89 km
# INFO:root:Generation 250: Current best cost = 65792.89 km
# INFO:root:Elapsed Time: 2.26 minutes | Estimated Remaining Time: 6.79 minutes
# INFO:root:Generation 251: New best cost = 65573.29 km
# INFO:root:Generation 252: New best cost = 65044.30 km
# INFO:root:Generation 254: New best cost = 64963.57 km
# INFO:root:Generation 255: New best cost = 64918.16 km
# INFO:root:Generation 257: New best cost = 64837.43 km
# INFO:root:Generation 262: New best cost = 64754.19 km
# INFO:root:Generation 264: New best cost = 64706.49 km
# INFO:root:Generation 266: New best cost = 64657.58 km
# INFO:root:Generation 267: New best cost = 64617.01 km
# INFO:root:Generation 269: New best cost = 64568.10 km
# INFO:root:Generation 270: New best cost = 64544.67 km
# INFO:root:Generation 271: New best cost = 64515.66 km
# INFO:root:Generation 272: New best cost = 64309.88 km
# INFO:root:Generation 273: New best cost = 64280.72 km
# INFO:root:Generation 274: New best cost = 63919.03 km
# INFO:root:Generation 275: New best cost = 63687.95 km
# INFO:root:Generation 276: New best cost = 63417.57 km
# INFO:root:Generation 277: New best cost = 63359.31 km
# INFO:root:Generation 278: New best cost = 63349.75 km
# INFO:root:Generation 279: New best cost = 63261.66 km
# INFO:root:Generation 281: New best cost = 63144.76 km
# INFO:root:Generation 285: New best cost = 62943.67 km
# INFO:root:Generation 287: New best cost = 62939.59 km
# INFO:root:Generation 288: New best cost = 62799.04 km
# INFO:root:Generation 300: Current best cost = 62799.04 km
# INFO:root:Elapsed Time: 2.71 minutes | Estimated Remaining Time: 6.33 minutes
# INFO:root:Generation 309: New best cost = 62754.63 km
# INFO:root:Generation 319: New best cost = 62605.29 km
# INFO:root:Generation 324: New best cost = 62376.51 km
# INFO:root:Generation 329: New best cost = 60342.93 km
# INFO:root:Generation 340: New best cost = 60304.76 km
# INFO:root:Generation 342: New best cost = 60166.28 km
# INFO:root:Generation 344: New best cost = 60156.48 km
# INFO:root:Generation 346: New best cost = 60058.33 km
# INFO:root:Generation 347: New best cost = 60010.64 km
# INFO:root:Generation 349: New best cost = 59901.92 km
# INFO:root:Generation 350: Current best cost = 59901.92 km
# INFO:root:Elapsed Time: 3.16 minutes | Estimated Remaining Time: 5.87 minutes
# INFO:root:Generation 351: New best cost = 59855.27 km
# INFO:root:Generation 353: New best cost = 59737.63 km
# INFO:root:Generation 355: New best cost = 59687.89 km
# INFO:root:Generation 356: New best cost = 59642.24 km
# INFO:root:Generation 362: New best cost = 59524.18 km
# INFO:root:Generation 364: New best cost = 59279.65 km
# INFO:root:Generation 366: New best cost = 59270.65 km
# INFO:root:Generation 367: New best cost = 59029.01 km
# INFO:root:Generation 369: New best cost = 58931.15 km
# INFO:root:Generation 370: New best cost = 58850.06 km
# INFO:root:Generation 371: New best cost = 58752.20 km
# INFO:root:Generation 372: New best cost = 58135.19 km
# INFO:root:Generation 379: New best cost = 58018.50 km
# INFO:root:Generation 385: New best cost = 57998.57 km
# INFO:root:Generation 387: New best cost = 57859.33 km
# INFO:root:Generation 390: New best cost = 57848.51 km
# INFO:root:Generation 392: New best cost = 57816.01 km
# INFO:root:Generation 395: New best cost = 56832.10 km
# INFO:root:Generation 400: Current best cost = 56832.10 km
# INFO:root:Elapsed Time: 3.61 minutes | Estimated Remaining Time: 5.41 minutes
# INFO:root:Generation 401: New best cost = 56514.76 km
# INFO:root:Generation 402: New best cost = 56512.75 km
# INFO:root:Generation 405: New best cost = 56045.46 km
# INFO:root:Generation 415: New best cost = 56041.42 km
# INFO:root:Generation 418: New best cost = 56001.47 km
# INFO:root:Generation 420: New best cost = 55206.99 km
# INFO:root:Generation 421: New best cost = 55167.04 km
# INFO:root:Generation 422: New best cost = 55071.02 km
# INFO:root:Generation 424: New best cost = 55031.62 km
# INFO:root:Generation 442: New best cost = 55019.59 km
# INFO:root:Generation 443: New best cost = 54895.04 km
# INFO:root:Generation 445: New best cost = 54726.86 km
# INFO:root:Generation 448: New best cost = 54477.17 km
# INFO:root:Generation 450: New best cost = 54271.72 km
# INFO:root:Generation 450: Current best cost = 54271.72 km
# INFO:root:Elapsed Time: 4.06 minutes | Estimated Remaining Time: 4.96 minutes
# INFO:root:Generation 456: New best cost = 54132.70 km
# INFO:root:Generation 474: New best cost = 54056.94 km
# INFO:root:Generation 475: New best cost = 54001.92 km
# INFO:root:Generation 476: New best cost = 53801.01 km
# INFO:root:Generation 478: New best cost = 53685.83 km
# INFO:root:Generation 482: New best cost = 53560.25 km
# INFO:root:Generation 487: New best cost = 53316.56 km
# INFO:root:Generation 491: New best cost = 52821.25 km
# INFO:root:Generation 500: Current best cost = 52821.25 km
# INFO:root:Elapsed Time: 4.51 minutes | Estimated Remaining Time: 4.51 minutes
# INFO:root:Generation 509: New best cost = 52786.06 km
# INFO:root:Generation 514: New best cost = 51790.31 km
# INFO:root:Generation 517: New best cost = 51289.36 km
# INFO:root:Generation 519: New best cost = 51278.91 km
# INFO:root:Generation 524: New best cost = 51215.03 km
# INFO:root:Generation 546: New best cost = 51214.25 km
# INFO:root:Generation 547: New best cost = 51084.18 km
# INFO:root:Generation 549: New best cost = 51083.40 km
# INFO:root:Generation 550: Current best cost = 51083.40 km
# INFO:root:Elapsed Time: 4.96 minutes | Estimated Remaining Time: 4.06 minutes
# INFO:root:Generation 600: Current best cost = 51083.40 km
# INFO:root:Elapsed Time: 5.41 minutes | Estimated Remaining Time: 3.60 minutes
# INFO:root:Generation 628: New best cost = 51043.33 km
# INFO:root:Generation 642: New best cost = 50879.76 km
# INFO:root:Generation 650: Current best cost = 50879.76 km
# INFO:root:Elapsed Time: 5.85 minutes | Estimated Remaining Time: 3.15 minutes
# INFO:root:Generation 677: New best cost = 50869.06 km
# INFO:root:Generation 693: New best cost = 50704.83 km
# INFO:root:Generation 699: New best cost = 50506.61 km
# INFO:root:Generation 700: Current best cost = 50506.61 km
# INFO:root:Elapsed Time: 6.29 minutes | Estimated Remaining Time: 2.70 minutes
# INFO:root:Generation 713: New best cost = 50009.61 km
# INFO:root:Generation 723: New best cost = 49733.34 km
# INFO:root:Generation 750: Current best cost = 49733.34 km
# INFO:root:Elapsed Time: 6.74 minutes | Estimated Remaining Time: 2.25 minutes
# INFO:root:Generation 775: New best cost = 49703.64 km
# INFO:root:Generation 777: New best cost = 49508.00 km
# INFO:root:Generation 787: New best cost = 49430.48 km
# INFO:root:Generation 800: New best cost = 49430.44 km
# INFO:root:Generation 800: Current best cost = 49430.44 km
# INFO:root:Elapsed Time: 7.18 minutes | Estimated Remaining Time: 1.80 minutes
# INFO:root:Generation 850: Current best cost = 49430.44 km
# INFO:root:Elapsed Time: 7.63 minutes | Estimated Remaining Time: 1.35 minutes
# INFO:root:Generation 858: New best cost = 49429.54 km
# INFO:root:Generation 900: Current best cost = 49429.54 km
# INFO:root:Elapsed Time: 8.08 minutes | Estimated Remaining Time: 0.90 minutes
# INFO:root:Generation 927: New best cost = 49424.43 km
# INFO:root:Generation 950: Current best cost = 49424.43 km
# INFO:root:Elapsed Time: 8.52 minutes | Estimated Remaining Time: 0.45 minutes
# INFO:root:Generation 1000: Current best cost = 49424.43 km
# INFO:root:Elapsed Time: 8.97 minutes | Estimated Remaining Time: 0.00 minutes
# INFO:root:Best solution found with cost = 49424.43 km in 538.21 seconds at generation 927
# INFO:root:Completed TSP for cities/russia.csv. Best cost: 49424.43 km at generation 927
# INFO:root:Processing cities/us.csv with 326 cities. Population size set to 300.
# INFO:root:Generation 1: New best cost = 549570.17 km
# INFO:root:Generation 3: New best cost = 541535.02 km
# INFO:root:Generation 4: New best cost = 529484.71 km
# INFO:root:Generation 5: New best cost = 521267.47 km
# INFO:root:Generation 6: New best cost = 513062.27 km
# INFO:root:Generation 7: New best cost = 512878.26 km
# INFO:root:Generation 9: New best cost = 504461.98 km
# INFO:root:Generation 10: New best cost = 499171.38 km
# INFO:root:Generation 11: New best cost = 492383.70 km
# INFO:root:Generation 12: New best cost = 480749.37 km
# INFO:root:Generation 14: New best cost = 475573.01 km
# INFO:root:Generation 15: New best cost = 468148.62 km
# INFO:root:Generation 16: New best cost = 463181.70 km
# INFO:root:Generation 17: New best cost = 447349.83 km
# INFO:root:Generation 18: New best cost = 445844.28 km
# INFO:root:Generation 19: New best cost = 442079.09 km
# INFO:root:Generation 20: New best cost = 437037.30 km
# INFO:root:Generation 21: New best cost = 435817.97 km
# INFO:root:Generation 22: New best cost = 428681.97 km
# INFO:root:Generation 23: New best cost = 426879.31 km
# INFO:root:Generation 24: New best cost = 415462.53 km
# INFO:root:Generation 27: New best cost = 405287.45 km
# INFO:root:Generation 28: New best cost = 402945.29 km
# INFO:root:Generation 29: New best cost = 400144.76 km
# INFO:root:Generation 30: New best cost = 397199.28 km
# INFO:root:Generation 31: New best cost = 392652.07 km
# INFO:root:Generation 32: New best cost = 387944.15 km
# INFO:root:Generation 33: New best cost = 381430.67 km
# INFO:root:Generation 34: New best cost = 378163.27 km
# INFO:root:Generation 35: New best cost = 374922.06 km
# INFO:root:Generation 36: New best cost = 372436.46 km
# INFO:root:Generation 37: New best cost = 368936.74 km
# INFO:root:Generation 38: New best cost = 363365.10 km
# INFO:root:Generation 39: New best cost = 362666.97 km
# INFO:root:Generation 40: New best cost = 357612.78 km
# INFO:root:Generation 41: New best cost = 354845.27 km
# INFO:root:Generation 42: New best cost = 352538.07 km
# INFO:root:Generation 43: New best cost = 348647.97 km
# INFO:root:Generation 44: New best cost = 344460.70 km
# INFO:root:Generation 45: New best cost = 339416.55 km
# INFO:root:Generation 46: New best cost = 336685.27 km
# INFO:root:Generation 47: New best cost = 331823.79 km
# INFO:root:Generation 48: New best cost = 329103.97 km
# INFO:root:Generation 49: New best cost = 324340.32 km
# INFO:root:Generation 50: New best cost = 323823.31 km
# INFO:root:Generation 50: Current best cost = 323823.31 km
# INFO:root:Elapsed Time: 2.08 minutes | Estimated Remaining Time: 39.52 minutes
# INFO:root:Generation 51: New best cost = 322934.60 km
# INFO:root:Generation 52: New best cost = 318863.37 km
# INFO:root:Generation 53: New best cost = 316680.33 km
# INFO:root:Generation 54: New best cost = 311529.92 km
# INFO:root:Generation 55: New best cost = 309187.46 km
# INFO:root:Generation 56: New best cost = 307556.11 km
# INFO:root:Generation 57: New best cost = 306183.50 km
# INFO:root:Generation 58: New best cost = 304259.74 km
# INFO:root:Generation 59: New best cost = 302081.89 km
# INFO:root:Generation 60: New best cost = 301604.59 km
# INFO:root:Generation 61: New best cost = 300001.48 km
# INFO:root:Generation 62: New best cost = 299471.16 km
# INFO:root:Generation 63: New best cost = 298639.41 km
# INFO:root:Generation 64: New best cost = 296067.87 km
# INFO:root:Generation 65: New best cost = 294387.36 km
# INFO:root:Generation 66: New best cost = 291928.19 km
# INFO:root:Generation 67: New best cost = 291326.83 km
# INFO:root:Generation 68: New best cost = 289655.05 km
# INFO:root:Generation 69: New best cost = 288712.30 km
# INFO:root:Generation 70: New best cost = 287728.93 km
# INFO:root:Generation 71: New best cost = 285649.79 km
# INFO:root:Generation 72: New best cost = 285647.95 km
# INFO:root:Generation 73: New best cost = 284322.52 km
# INFO:root:Generation 74: New best cost = 283845.03 km
# INFO:root:Generation 75: New best cost = 282267.35 km
# INFO:root:Generation 76: New best cost = 281623.20 km
# INFO:root:Generation 77: New best cost = 279676.30 km
# INFO:root:Generation 78: New best cost = 278729.73 km
# INFO:root:Generation 79: New best cost = 274870.70 km
# INFO:root:Generation 81: New best cost = 272095.62 km
# INFO:root:Generation 82: New best cost = 271661.15 km
# INFO:root:Generation 83: New best cost = 268795.26 km
# INFO:root:Generation 85: New best cost = 265080.15 km
# INFO:root:Generation 86: New best cost = 264544.18 km
# INFO:root:Generation 87: New best cost = 262779.70 km
# INFO:root:Generation 88: New best cost = 262442.04 km
# INFO:root:Generation 89: New best cost = 258585.15 km
# INFO:root:Generation 90: New best cost = 258247.49 km
# INFO:root:Generation 91: New best cost = 257002.86 km
# INFO:root:Generation 92: New best cost = 255921.30 km
# INFO:root:Generation 94: New best cost = 254764.46 km
# INFO:root:Generation 95: New best cost = 254231.40 km
# INFO:root:Generation 96: New best cost = 252811.74 km
# INFO:root:Generation 97: New best cost = 251799.15 km
# INFO:root:Generation 98: New best cost = 249630.16 km
# INFO:root:Generation 99: New best cost = 247634.81 km
# INFO:root:Generation 100: New best cost = 246112.61 km
# INFO:root:Generation 100: Current best cost = 246112.61 km
# INFO:root:Elapsed Time: 4.13 minutes | Estimated Remaining Time: 37.13 minutes
# INFO:root:Generation 101: New best cost = 245188.45 km
# INFO:root:Generation 102: New best cost = 244158.21 km
# INFO:root:Generation 103: New best cost = 243409.08 km
# INFO:root:Generation 104: New best cost = 242117.98 km
# INFO:root:Generation 105: New best cost = 241542.34 km
# INFO:root:Generation 106: New best cost = 239624.53 km
# INFO:root:Generation 107: New best cost = 237529.53 km
# INFO:root:Generation 108: New best cost = 232349.84 km
# INFO:root:Generation 110: New best cost = 230474.23 km
# INFO:root:Generation 111: New best cost = 230176.96 km
# INFO:root:Generation 112: New best cost = 228890.56 km
# INFO:root:Generation 113: New best cost = 227316.83 km
# INFO:root:Generation 114: New best cost = 226792.04 km
# INFO:root:Generation 115: New best cost = 224343.90 km
# INFO:root:Generation 116: New best cost = 222913.67 km
# INFO:root:Generation 117: New best cost = 220724.57 km
# INFO:root:Generation 118: New best cost = 219375.22 km
# INFO:root:Generation 119: New best cost = 217619.94 km
# INFO:root:Generation 120: New best cost = 216288.67 km
# INFO:root:Generation 121: New best cost = 215714.71 km
# INFO:root:Generation 122: New best cost = 214030.56 km
# INFO:root:Generation 123: New best cost = 213093.87 km
# INFO:root:Generation 124: New best cost = 211303.47 km
# INFO:root:Generation 125: New best cost = 210373.02 km
# INFO:root:Generation 126: New best cost = 209470.25 km
# INFO:root:Generation 127: New best cost = 208765.22 km
# INFO:root:Generation 128: New best cost = 207374.62 km
# INFO:root:Generation 129: New best cost = 206669.59 km
# INFO:root:Generation 130: New best cost = 205577.45 km
# INFO:root:Generation 132: New best cost = 205020.11 km
# INFO:root:Generation 133: New best cost = 204157.38 km
# INFO:root:Generation 134: New best cost = 203235.93 km
# INFO:root:Generation 135: New best cost = 202739.88 km
# INFO:root:Generation 136: New best cost = 202221.90 km
# INFO:root:Generation 137: New best cost = 200945.59 km
# INFO:root:Generation 138: New best cost = 200063.49 km
# INFO:root:Generation 139: New best cost = 199938.63 km
# INFO:root:Generation 140: New best cost = 199865.63 km
# INFO:root:Generation 141: New best cost = 199064.18 km
# INFO:root:Generation 142: New best cost = 196852.38 km
# INFO:root:Generation 144: New best cost = 194982.40 km
# INFO:root:Generation 145: New best cost = 193405.40 km
# INFO:root:Generation 146: New best cost = 192453.31 km
# INFO:root:Generation 147: New best cost = 191186.26 km
# INFO:root:Generation 148: New best cost = 190659.89 km
# INFO:root:Generation 149: New best cost = 189357.15 km
# INFO:root:Generation 150: New best cost = 189159.99 km
# INFO:root:Generation 150: Current best cost = 189159.99 km
# INFO:root:Elapsed Time: 6.17 minutes | Estimated Remaining Time: 34.99 minutes
# INFO:root:Generation 151: New best cost = 188222.69 km
# INFO:root:Generation 152: New best cost = 185932.07 km
# INFO:root:Generation 153: New best cost = 185391.34 km
# INFO:root:Generation 154: New best cost = 184860.25 km
# INFO:root:Generation 155: New best cost = 184163.31 km
# INFO:root:Generation 156: New best cost = 183606.32 km
# INFO:root:Generation 157: New best cost = 182103.00 km
# INFO:root:Generation 158: New best cost = 181562.27 km
# INFO:root:Generation 159: New best cost = 180579.59 km
# INFO:root:Generation 161: New best cost = 179281.91 km
# INFO:root:Generation 162: New best cost = 178702.27 km
# INFO:root:Generation 163: New best cost = 178498.39 km
# INFO:root:Generation 164: New best cost = 178093.59 km
# INFO:root:Generation 165: New best cost = 177410.28 km
# INFO:root:Generation 166: New best cost = 176690.36 km
# INFO:root:Generation 167: New best cost = 176041.73 km
# INFO:root:Generation 168: New best cost = 175463.23 km
# INFO:root:Generation 169: New best cost = 174970.30 km
# INFO:root:Generation 170: New best cost = 173967.85 km
# INFO:root:Generation 171: New best cost = 173335.79 km
# INFO:root:Generation 172: New best cost = 172687.16 km
# INFO:root:Generation 173: New best cost = 171453.40 km
# INFO:root:Generation 174: New best cost = 170804.76 km
# INFO:root:Generation 175: New best cost = 170439.11 km
# INFO:root:Generation 176: New best cost = 169891.66 km
# INFO:root:Generation 177: New best cost = 169691.08 km
# INFO:root:Generation 178: New best cost = 169122.67 km
# INFO:root:Generation 179: New best cost = 168449.78 km
# INFO:root:Generation 180: New best cost = 167801.15 km
# INFO:root:Generation 181: New best cost = 167619.36 km
# INFO:root:Generation 182: New best cost = 166394.40 km
# INFO:root:Generation 183: New best cost = 165142.76 km
# INFO:root:Generation 184: New best cost = 164566.51 km
# INFO:root:Generation 185: New best cost = 164378.50 km
# INFO:root:Generation 187: New best cost = 163993.18 km
# INFO:root:Generation 188: New best cost = 163512.61 km
# INFO:root:Generation 189: New best cost = 163270.67 km
# INFO:root:Generation 190: New best cost = 162748.18 km
# INFO:root:Generation 191: New best cost = 161995.41 km
# INFO:root:Generation 193: New best cost = 161044.97 km
# INFO:root:Generation 194: New best cost = 160901.81 km
# INFO:root:Generation 196: New best cost = 159797.84 km
# INFO:root:Generation 197: New best cost = 159694.41 km
# INFO:root:Generation 198: New best cost = 159160.64 km
# INFO:root:Generation 200: New best cost = 158748.22 km
# INFO:root:Generation 200: Current best cost = 158748.22 km
# INFO:root:Elapsed Time: 8.21 minutes | Estimated Remaining Time: 32.84 minutes
# INFO:root:Generation 201: New best cost = 158714.26 km
# INFO:root:Generation 203: New best cost = 158160.43 km
# INFO:root:Generation 204: New best cost = 157690.22 km
# INFO:root:Generation 206: New best cost = 156912.14 km
# INFO:root:Generation 207: New best cost = 156767.22 km
# INFO:root:Generation 208: New best cost = 156148.58 km
# INFO:root:Generation 209: New best cost = 155964.69 km
# INFO:root:Generation 210: New best cost = 155942.37 km
# INFO:root:Generation 211: New best cost = 155654.48 km
# INFO:root:Generation 212: New best cost = 155504.71 km
# INFO:root:Generation 213: New best cost = 154982.97 km
# INFO:root:Generation 215: New best cost = 154678.78 km
# INFO:root:Generation 216: New best cost = 154169.76 km
# INFO:root:Generation 217: New best cost = 153931.88 km
# INFO:root:Generation 219: New best cost = 153457.80 km
# INFO:root:Generation 222: New best cost = 153274.06 km
# INFO:root:Generation 223: New best cost = 153183.51 km
# INFO:root:Generation 224: New best cost = 152602.00 km
# INFO:root:Generation 225: New best cost = 152511.46 km
# INFO:root:Generation 226: New best cost = 152441.09 km
# INFO:root:Generation 227: New best cost = 152247.49 km
# INFO:root:Generation 228: New best cost = 152054.83 km
# INFO:root:Generation 229: New best cost = 151932.95 km
# INFO:root:Generation 230: New best cost = 151703.76 km
# INFO:root:Generation 232: New best cost = 151389.22 km
# INFO:root:Generation 233: New best cost = 151077.94 km
# INFO:root:Generation 234: New best cost = 150763.40 km
# INFO:root:Generation 235: New best cost = 150480.23 km
# INFO:root:Generation 236: New best cost = 150402.59 km
# INFO:root:Generation 237: New best cost = 150100.00 km
# INFO:root:Generation 238: New best cost = 150064.75 km
# INFO:root:Generation 239: New best cost = 150010.86 km
# INFO:root:Generation 240: New best cost = 149355.02 km
# INFO:root:Generation 241: New best cost = 149215.12 km
# INFO:root:Generation 242: New best cost = 148744.81 km
# INFO:root:Generation 244: New best cost = 147710.02 km
# INFO:root:Generation 246: New best cost = 147647.83 km
# INFO:root:Generation 247: New best cost = 147490.24 km
# INFO:root:Generation 248: New best cost = 147219.77 km
# INFO:root:Generation 249: New best cost = 147156.17 km
# INFO:root:Generation 250: New best cost = 146699.23 km
# INFO:root:Generation 250: Current best cost = 146699.23 km
# INFO:root:Elapsed Time: 10.24 minutes | Estimated Remaining Time: 30.72 minutes
# INFO:root:Generation 251: New best cost = 146592.90 km
# INFO:root:Generation 252: New best cost = 146336.32 km
# INFO:root:Generation 253: New best cost = 145720.00 km
# INFO:root:Generation 254: New best cost = 145154.86 km
# INFO:root:Generation 255: New best cost = 145076.61 km
# INFO:root:Generation 256: New best cost = 144654.79 km
# INFO:root:Generation 257: New best cost = 144183.12 km
# INFO:root:Generation 258: New best cost = 144041.70 km
# INFO:root:Generation 259: New best cost = 143776.35 km
# INFO:root:Generation 260: New best cost = 142687.79 km
# INFO:root:Generation 261: New best cost = 142364.56 km
# INFO:root:Generation 262: New best cost = 142054.67 km
# INFO:root:Generation 263: New best cost = 140869.22 km
# INFO:root:Generation 265: New best cost = 140414.53 km
# INFO:root:Generation 267: New best cost = 139960.89 km
# INFO:root:Generation 268: New best cost = 139506.20 km
# INFO:root:Generation 269: New best cost = 139162.40 km
# INFO:root:Generation 270: New best cost = 138976.14 km
# INFO:root:Generation 272: New best cost = 138904.17 km
# INFO:root:Generation 274: New best cost = 138587.15 km
# INFO:root:Generation 275: New best cost = 138473.86 km
# INFO:root:Generation 278: New best cost = 137766.02 km
# INFO:root:Generation 280: New best cost = 137457.42 km
# INFO:root:Generation 282: New best cost = 137305.30 km
# INFO:root:Generation 283: New best cost = 137196.31 km
# INFO:root:Generation 284: New best cost = 136862.76 km
# INFO:root:Generation 285: New best cost = 136418.65 km
# INFO:root:Generation 286: New best cost = 135625.81 km
# INFO:root:Generation 288: New best cost = 135116.09 km
# INFO:root:Generation 289: New best cost = 134873.67 km
# INFO:root:Generation 290: New best cost = 134797.55 km
# INFO:root:Generation 291: New best cost = 134020.31 km
# INFO:root:Generation 292: New best cost = 133678.06 km
# INFO:root:Generation 293: New best cost = 132825.83 km
# INFO:root:Generation 295: New best cost = 132585.57 km
# INFO:root:Generation 296: New best cost = 132471.41 km
# INFO:root:Generation 298: New best cost = 132231.15 km
# INFO:root:Generation 299: New best cost = 132164.48 km
# INFO:root:Generation 300: New best cost = 132164.28 km
# INFO:root:Generation 300: Current best cost = 132164.28 km
# INFO:root:Elapsed Time: 12.27 minutes | Estimated Remaining Time: 28.63 minutes
# INFO:root:Generation 301: New best cost = 132097.61 km
# INFO:root:Generation 302: New best cost = 132088.23 km
# INFO:root:Generation 304: New best cost = 132058.91 km
# INFO:root:Generation 305: New best cost = 131813.34 km
# INFO:root:Generation 307: New best cost = 131356.58 km
# INFO:root:Generation 309: New best cost = 131172.56 km
# INFO:root:Generation 311: New best cost = 131146.56 km
# INFO:root:Generation 312: New best cost = 131062.42 km
# INFO:root:Generation 313: New best cost = 130971.31 km
# INFO:root:Generation 314: New best cost = 130309.68 km
# INFO:root:Generation 315: New best cost = 130231.99 km
# INFO:root:Generation 316: New best cost = 129996.34 km
# INFO:root:Generation 317: New best cost = 129146.44 km
# INFO:root:Generation 318: New best cost = 128361.69 km
# INFO:root:Generation 319: New best cost = 128037.97 km
# INFO:root:Generation 325: New best cost = 127589.22 km
# INFO:root:Generation 326: New best cost = 127264.32 km
# INFO:root:Generation 327: New best cost = 127263.44 km
# INFO:root:Generation 328: New best cost = 126630.74 km
# INFO:root:Generation 329: New best cost = 126402.90 km
# INFO:root:Generation 331: New best cost = 126237.97 km
# INFO:root:Generation 332: New best cost = 126060.32 km
# INFO:root:Generation 333: New best cost = 125606.69 km
# INFO:root:Generation 335: New best cost = 125528.36 km
# INFO:root:Generation 336: New best cost = 124462.68 km
# INFO:root:Generation 337: New best cost = 124095.65 km
# INFO:root:Generation 338: New best cost = 123962.51 km
# INFO:root:Generation 339: New best cost = 123546.25 km
# INFO:root:Generation 340: New best cost = 123295.08 km
# INFO:root:Generation 341: New best cost = 122469.07 km
# INFO:root:Generation 342: New best cost = 122468.82 km
# INFO:root:Generation 343: New best cost = 122189.98 km
# INFO:root:Generation 345: New best cost = 121396.91 km
# INFO:root:Generation 346: New best cost = 121274.66 km
# INFO:root:Generation 347: New best cost = 121087.07 km
# INFO:root:Generation 348: New best cost = 120201.79 km
# INFO:root:Generation 349: New best cost = 120163.32 km
# INFO:root:Generation 350: New best cost = 120014.21 km
# INFO:root:Generation 350: Current best cost = 120014.21 km
# INFO:root:Elapsed Time: 14.30 minutes | Estimated Remaining Time: 26.56 minutes
# INFO:root:Generation 351: New best cost = 119874.86 km
# INFO:root:Generation 354: New best cost = 119711.70 km
# INFO:root:Generation 356: New best cost = 119190.86 km
# INFO:root:Generation 357: New best cost = 118611.90 km
# INFO:root:Generation 360: New best cost = 118568.53 km
# INFO:root:Generation 361: New best cost = 118479.03 km
# INFO:root:Generation 362: New best cost = 118410.25 km
# INFO:root:Generation 363: New best cost = 118339.30 km
# INFO:root:Generation 364: New best cost = 118244.51 km
# INFO:root:Generation 365: New best cost = 118098.38 km
# INFO:root:Generation 366: New best cost = 118075.38 km
# INFO:root:Generation 367: New best cost = 117988.66 km
# INFO:root:Generation 368: New best cost = 117835.91 km
# INFO:root:Generation 369: New best cost = 117812.91 km
# INFO:root:Generation 370: New best cost = 117573.75 km
# INFO:root:Generation 372: New best cost = 117552.12 km
# INFO:root:Generation 373: New best cost = 117485.95 km
# INFO:root:Generation 374: New best cost = 117025.44 km
# ...
# INFO:root:Generation 504: New best cost = 291170.47 km
# INFO:root:Generation 506: New best cost = 290883.07 km
# INFO:root:Generation 508: New best cost = 290524.71 km
# INFO:root:Generation 509: New best cost = 290454.79 km
# INFO:root:Generation 510: New best cost = 289502.50 km
# INFO:root:Generation 512: New best cost = 288647.18 km
# INFO:root:Generation 514: New best cost = 288212.10 km
# INFO:root:Generation 515: New best cost = 288192.77 km
# INFO:root:Generation 516: New best cost = 287841.66 km
# INFO:root:Generation 517: New best cost = 287706.02 km
# INFO:root:Generation 519: New best cost = 287251.63 km
# INFO:root:Generation 520: New best cost = 287246.95 km
# INFO:root:Generation 521: New best cost = 287241.51 km
# INFO:root:Generation 522: New best cost = 287062.16 km
# INFO:root:Generation 523: New best cost = 286797.55 km
# INFO:root:Generation 524: New best cost = 286600.88 km
# INFO:root:Generation 525: New best cost = 286220.48 km
# INFO:root:Generation 526: New best cost = 286009.61 km
# INFO:root:Generation 527: New best cost = 285771.07 km
# INFO:root:Generation 528: New best cost = 285437.49 km
# INFO:root:Generation 529: New best cost = 285417.20 km
# INFO:root:Generation 530: New best cost = 285281.40 km
# INFO:root:Generation 531: New best cost = 284918.36 km
# INFO:root:Generation 533: New best cost = 284385.01 km
# INFO:root:Generation 534: New best cost = 283589.68 km
# INFO:root:Generation 535: New best cost = 283497.45 km
# INFO:root:Generation 536: New best cost = 283115.26 km
# INFO:root:Generation 537: New best cost = 282185.98 km
# INFO:root:Generation 539: New best cost = 281656.61 km
# INFO:root:Generation 541: New best cost = 281278.11 km
# INFO:root:Generation 544: New best cost = 280642.41 km
# INFO:root:Generation 545: New best cost = 280635.54 km
# INFO:root:Generation 546: New best cost = 280024.49 km
# INFO:root:Generation 549: New best cost = 279512.48 km
# INFO:root:Generation 550: Current best cost = 279512.48 km
# INFO:root:Elapsed Time: 70.53 minutes | Estimated Remaining Time: 57.70 minutes
# INFO:root:Generation 552: New best cost = 279173.94 km
# INFO:root:Generation 554: New best cost = 278992.28 km
# INFO:root:Generation 555: New best cost = 278818.98 km
# INFO:root:Generation 556: New best cost = 278093.82 km
# INFO:root:Generation 559: New best cost = 277867.44 km
# INFO:root:Generation 560: New best cost = 277799.12 km
# INFO:root:Generation 561: New best cost = 277766.09 km
# INFO:root:Generation 562: New best cost = 277412.38 km
# INFO:root:Generation 564: New best cost = 277051.78 km
# INFO:root:Generation 565: New best cost = 276532.27 km
# INFO:root:Generation 566: New best cost = 275905.09 km
# INFO:root:Generation 567: New best cost = 275301.94 km
# INFO:root:Generation 568: New best cost = 274562.12 km
# INFO:root:Generation 572: New best cost = 274175.99 km
# INFO:root:Generation 573: New best cost = 274113.73 km
# INFO:root:Generation 575: New best cost = 273665.78 km
# INFO:root:Generation 577: New best cost = 273621.52 km
# INFO:root:Generation 578: New best cost = 273155.74 km
# INFO:root:Generation 579: New best cost = 272816.51 km
# INFO:root:Generation 580: New best cost = 272772.25 km
# INFO:root:Generation 581: New best cost = 272136.13 km
# INFO:root:Generation 583: New best cost = 271798.31 km
# INFO:root:Generation 584: New best cost = 271754.05 km
# INFO:root:Generation 585: New best cost = 270860.16 km
# INFO:root:Generation 586: New best cost = 269922.64 km
# INFO:root:Generation 590: New best cost = 269337.76 km
# INFO:root:Generation 595: New best cost = 269280.09 km
# INFO:root:Generation 596: New best cost = 269182.65 km
# INFO:root:Generation 598: New best cost = 268609.95 km
# INFO:root:Generation 599: New best cost = 268459.92 km
# INFO:root:Generation 600: Current best cost = 268459.92 km
# INFO:root:Elapsed Time: 76.89 minutes | Estimated Remaining Time: 51.26 minutes
# INFO:root:Generation 601: New best cost = 268269.92 km
# INFO:root:Generation 602: New best cost = 268118.14 km
# INFO:root:Generation 603: New best cost = 267869.75 km
# INFO:root:Generation 604: New best cost = 267208.34 km
# INFO:root:Generation 605: New best cost = 266521.73 km
# INFO:root:Generation 608: New best cost = 265836.99 km
# INFO:root:Generation 610: New best cost = 265396.90 km
# INFO:root:Generation 611: New best cost = 264870.12 km
# INFO:root:Generation 612: New best cost = 264635.07 km
# INFO:root:Generation 613: New best cost = 264111.74 km
# INFO:root:Generation 614: New best cost = 263842.32 km
# INFO:root:Generation 615: New best cost = 263776.51 km
# INFO:root:Generation 616: New best cost = 263410.10 km
# INFO:root:Generation 617: New best cost = 263083.91 km
# INFO:root:Generation 618: New best cost = 262760.13 km
# INFO:root:Generation 619: New best cost = 262377.15 km
# INFO:root:Generation 620: New best cost = 262074.57 km
# INFO:root:Generation 621: New best cost = 261883.17 km
# INFO:root:Generation 622: New best cost = 261564.82 km
# INFO:root:Generation 623: New best cost = 261015.27 km
# INFO:root:Generation 624: New best cost = 260774.40 km
# INFO:root:Generation 625: New best cost = 260677.78 km
# INFO:root:Generation 626: New best cost = 260576.61 km
# INFO:root:Generation 627: New best cost = 260007.57 km
# INFO:root:Generation 628: New best cost = 259634.61 km
# INFO:root:Generation 629: New best cost = 259319.14 km
# INFO:root:Generation 630: New best cost = 259207.78 km
# INFO:root:Generation 631: New best cost = 258993.48 km
# INFO:root:Generation 635: New best cost = 258870.24 km
# INFO:root:Generation 636: New best cost = 258824.35 km
# INFO:root:Generation 637: New best cost = 258564.74 km
# INFO:root:Generation 638: New best cost = 257513.11 km
# INFO:root:Generation 642: New best cost = 256710.86 km
# INFO:root:Generation 645: New best cost = 256618.89 km
# INFO:root:Generation 647: New best cost = 256524.17 km
# INFO:root:Generation 648: New best cost = 256352.05 km
# INFO:root:Generation 649: New best cost = 256165.36 km
# INFO:root:Generation 650: New best cost = 256014.37 km
# INFO:root:Generation 650: Current best cost = 256014.37 km
# INFO:root:Elapsed Time: 83.27 minutes | Estimated Remaining Time: 44.84 minutes
# INFO:root:Generation 651: New best cost = 255652.34 km
# INFO:root:Generation 652: New best cost = 255465.65 km
# INFO:root:Generation 653: New best cost = 255020.07 km
# INFO:root:Generation 654: New best cost = 254651.65 km
# INFO:root:Generation 655: New best cost = 254386.09 km
# INFO:root:Generation 656: New best cost = 254207.03 km
# INFO:root:Generation 657: New best cost = 253624.17 km
# INFO:root:Generation 658: New best cost = 253445.11 km
# INFO:root:Generation 659: New best cost = 253417.03 km
# INFO:root:Generation 660: New best cost = 253135.61 km
# INFO:root:Generation 663: New best cost = 253063.91 km
# INFO:root:Generation 665: New best cost = 252928.32 km
# INFO:root:Generation 666: New best cost = 252421.58 km
# INFO:root:Generation 667: New best cost = 252285.99 km
# INFO:root:Generation 668: New best cost = 252115.96 km
# INFO:root:Generation 669: New best cost = 251893.23 km
# INFO:root:Generation 670: New best cost = 251757.64 km
# INFO:root:Generation 672: New best cost = 251678.26 km
# INFO:root:Generation 674: New best cost = 251661.20 km
# INFO:root:Generation 675: New best cost = 251115.46 km
# INFO:root:Generation 677: New best cost = 250835.51 km
# INFO:root:Generation 686: New best cost = 250286.97 km
# INFO:root:Generation 690: New best cost = 250255.29 km
# INFO:root:Generation 691: New best cost = 249820.49 km
# INFO:root:Generation 693: New best cost = 249700.69 km
# INFO:root:Generation 695: New best cost = 249389.59 km
# INFO:root:Generation 698: New best cost = 249071.76 km
# INFO:root:Generation 700: New best cost = 248900.77 km
# INFO:root:Generation 700: Current best cost = 248900.77 km
# INFO:root:Elapsed Time: 89.65 minutes | Estimated Remaining Time: 38.42 minutes
# INFO:root:Generation 702: New best cost = 248856.99 km
# INFO:root:Generation 703: New best cost = 248665.86 km
# INFO:root:Generation 704: New best cost = 248288.73 km
# INFO:root:Generation 706: New best cost = 248143.47 km
# INFO:root:Generation 707: New best cost = 248119.87 km
# INFO:root:Generation 708: New best cost = 247334.10 km
# INFO:root:Generation 710: New best cost = 247190.34 km
# INFO:root:Generation 711: New best cost = 246327.05 km
# INFO:root:Generation 713: New best cost = 246183.61 km
# INFO:root:Generation 715: New best cost = 245899.99 km
# INFO:root:Generation 719: New best cost = 245745.50 km
# INFO:root:Generation 721: New best cost = 245251.47 km
# INFO:root:Generation 722: New best cost = 245200.41 km
# INFO:root:Generation 723: New best cost = 245146.53 km
# INFO:root:Generation 724: New best cost = 244706.39 km
# INFO:root:Generation 725: New best cost = 244575.47 km
# INFO:root:Generation 726: New best cost = 244257.88 km
# INFO:root:Generation 727: New best cost = 244218.64 km
# INFO:root:Generation 728: New best cost = 244101.91 km
# INFO:root:Generation 729: New best cost = 244062.68 km
# INFO:root:Generation 731: New best cost = 243757.18 km
# INFO:root:Generation 735: New best cost = 243754.75 km
# INFO:root:Generation 736: New best cost = 243219.78 km
# INFO:root:Generation 738: New best cost = 243205.32 km
# INFO:root:Generation 739: New best cost = 243065.97 km
# INFO:root:Generation 740: New best cost = 242370.95 km
# INFO:root:Generation 743: New best cost = 242091.80 km
# INFO:root:Generation 745: New best cost = 241721.85 km
# INFO:root:Generation 747: New best cost = 241362.67 km
# INFO:root:Generation 750: Current best cost = 241362.67 km
# INFO:root:Elapsed Time: 96.04 minutes | Estimated Remaining Time: 32.01 minutes
# INFO:root:Generation 758: New best cost = 241201.35 km
# INFO:root:Generation 760: New best cost = 241148.03 km
# INFO:root:Generation 761: New best cost = 241129.46 km
# INFO:root:Generation 762: New best cost = 241051.54 km
# INFO:root:Generation 767: New best cost = 240886.80 km
# INFO:root:Generation 772: New best cost = 240596.85 km
# INFO:root:Generation 781: New best cost = 240545.26 km
# INFO:root:Generation 783: New best cost = 240422.40 km
# INFO:root:Generation 786: New best cost = 240240.57 km
# INFO:root:Generation 789: New best cost = 240155.36 km
# INFO:root:Generation 791: New best cost = 239912.85 km
# INFO:root:Generation 794: New best cost = 239722.74 km
# INFO:root:Generation 796: New best cost = 239716.06 km
# INFO:root:Generation 800: Current best cost = 239716.06 km
# INFO:root:Elapsed Time: 102.44 minutes | Estimated Remaining Time: 25.61 minutes
# INFO:root:Generation 803: New best cost = 239695.48 km
# INFO:root:Generation 804: New best cost = 239538.25 km
# INFO:root:Generation 805: New best cost = 239503.65 km
# INFO:root:Generation 806: New best cost = 239448.98 km
# INFO:root:Generation 807: New best cost = 238834.71 km
# INFO:root:Generation 809: New best cost = 238738.35 km
# INFO:root:Generation 811: New best cost = 238292.27 km
# INFO:root:Generation 815: New best cost = 237623.46 km
# INFO:root:Generation 817: New best cost = 237443.30 km
# INFO:root:Generation 818: New best cost = 237174.69 km
# INFO:root:Generation 819: New best cost = 236994.53 km
# INFO:root:Generation 820: New best cost = 236886.33 km
# INFO:root:Generation 821: New best cost = 236848.28 km
# INFO:root:Generation 822: New best cost = 236712.03 km
# INFO:root:Generation 823: New best cost = 236572.42 km
# INFO:root:Generation 824: New best cost = 236381.72 km
# INFO:root:Generation 825: New best cost = 236042.45 km
# INFO:root:Generation 827: New best cost = 235864.34 km
# INFO:root:Generation 828: New best cost = 235583.88 km
# INFO:root:Generation 841: New best cost = 235471.07 km
# INFO:root:Generation 844: New best cost = 235464.01 km
# INFO:root:Generation 846: New best cost = 235460.40 km
# INFO:root:Generation 847: New best cost = 234743.91 km
# INFO:root:Generation 848: New best cost = 234737.42 km
# INFO:root:Generation 849: New best cost = 234541.47 km
# INFO:root:Generation 850: Current best cost = 234541.47 km
# INFO:root:Elapsed Time: 108.80 minutes | Estimated Remaining Time: 19.20 minutes
# INFO:root:Generation 852: New best cost = 234482.92 km
# INFO:root:Generation 853: New best cost = 234467.28 km
# INFO:root:Generation 854: New best cost = 234435.60 km
# INFO:root:Generation 856: New best cost = 234400.55 km
# INFO:root:Generation 857: New best cost = 234350.16 km
# INFO:root:Generation 859: New best cost = 234056.89 km
# INFO:root:Generation 861: New best cost = 233771.71 km
# INFO:root:Generation 863: New best cost = 233770.07 km
# INFO:root:Generation 868: New best cost = 233604.76 km
# INFO:root:Generation 871: New best cost = 233568.95 km
# INFO:root:Generation 874: New best cost = 233405.10 km
# INFO:root:Generation 877: New best cost = 233311.51 km
# INFO:root:Generation 878: New best cost = 232325.83 km
# INFO:root:Generation 880: New best cost = 232139.33 km
# INFO:root:Generation 881: New best cost = 231717.33 km
# INFO:root:Generation 882: New best cost = 230975.72 km
# INFO:root:Generation 883: New best cost = 230908.04 km
# INFO:root:Generation 885: New best cost = 230763.93 km
# INFO:root:Generation 900: New best cost = 230714.98 km
# INFO:root:Generation 900: Current best cost = 230714.98 km
# INFO:root:Elapsed Time: 115.17 minutes | Estimated Remaining Time: 12.80 minutes
# INFO:root:Generation 902: New best cost = 230581.65 km
# INFO:root:Generation 903: New best cost = 230479.53 km
# INFO:root:Generation 905: New best cost = 230269.35 km
# INFO:root:Generation 907: New best cost = 230246.39 km
# INFO:root:Generation 909: New best cost = 229914.00 km
# INFO:root:Generation 912: New best cost = 229716.83 km
# INFO:root:Generation 914: New best cost = 229680.16 km
# INFO:root:Generation 931: New best cost = 229613.39 km
# INFO:root:Generation 933: New best cost = 229575.96 km
# INFO:root:Generation 934: New best cost = 229530.95 km
# INFO:root:Generation 935: New best cost = 229504.81 km
# INFO:root:Generation 936: New best cost = 229493.53 km
# INFO:root:Generation 937: New best cost = 229278.78 km
# INFO:root:Generation 950: Current best cost = 229278.78 km
# INFO:root:Elapsed Time: 121.52 minutes | Estimated Remaining Time: 6.40 minutes
# INFO:root:Generation 953: New best cost = 228640.96 km
# INFO:root:Generation 957: New best cost = 228549.12 km
# INFO:root:Generation 960: New best cost = 228365.51 km
# INFO:root:Generation 971: New best cost = 228363.28 km
# INFO:root:Generation 973: New best cost = 228221.91 km
# INFO:root:Generation 976: New best cost = 228161.52 km
# INFO:root:Generation 1000: Current best cost = 228161.52 km
# INFO:root:Elapsed Time: 127.86 minutes | Estimated Remaining Time: 0.00 minutes
# INFO:root:Best solution found with cost = 228161.52 km in 7671.45 seconds at generation 976
# INFO:root:Completed TSP for cities/china.csv. Best cost: 228161.52 km at generation 976
# INFO:root:EA Results successfully saved to tsp_results_ea.csv
# INFO:root:Processing cities/italy.csv with 46 cities using greedy algorithm.
# INFO:root:result: Found a path of 46 steps, total length 4436.03km
# INFO:root:Completed TSP for cities/italy.csv using greedy approach. Best cost: 4436.03 km at step 46
# INFO:root:Processing cities/vanuatu.csv with 8 cities using greedy algorithm.
# INFO:root:result: Found a path of 8 steps, total length 1475.53km
# INFO:root:Completed TSP for cities/vanuatu.csv using greedy approach. Best cost: 1475.53 km at step 8
# INFO:root:Processing cities/russia.csv with 167 cities using greedy algorithm.
# EA Results saved to tsp_results_ea.csv
# INFO:root:result: Found a path of 167 steps, total length 42334.16km
# INFO:root:Completed TSP for cities/russia.csv using greedy approach. Best cost: 42334.16 km at step 167
# INFO:root:Processing cities/us.csv with 326 cities using greedy algorithm.
# INFO:root:result: Found a path of 326 steps, total length 48050.03km
# INFO:root:Completed TSP for cities/us.csv using greedy approach. Best cost: 48050.03 km at step 326
# INFO:root:Processing cities/china.csv with 726 cities using greedy algorithm.
# INFO:root:result: Found a path of 726 steps, total length 63962.92km
# INFO:root:Completed TSP for cities/china.csv using greedy approach. Best cost: 63962.92 km at step 726
# INFO:root:Greedy Results successfully saved to tsp_results_greedy.csv
# Greedy Results saved to tsp_results_greedy.csv

# %% [markdown]
# **Note:** The number of generations for the Genetic Algorithm has been set to `1000` as per your original script, which may take several hours to complete depending on the dataset size and computational resources.
#
# ## Results and Analysis
#
# After running the experiments, the results from both the Genetic and Greedy algorithms are saved in `tsp_results_ea.csv` and `tsp_results_greedy.csv` respectively. These results include the filename, number of cities, best cost in kilometers, and the best tour found.
#
# **Sample Output:**
# ```plaintext
# EA Results saved to tsp_results_ea.csv
# Greedy Results saved to tsp_results_greedy.csv
# ```
#
# The results provide insights into the performance of each algorithm across different datasets. By analyzing the best costs and tours, we can evaluate the efficiency and effectiveness of the Genetic and Greedy approaches in solving the TSP.
#
# ## Plotting Progressions
#
# To visualize the performance of both algorithms over their execution, we can plot the cost progression across generations (for the Genetic Algorithm) and steps (for the Greedy Algorithm). This helps in understanding how each algorithm converges towards a solution.
#
# ### Plotting EA Progression

# %%
def plot_ea_progress(ea_progressions, output_dir="plots/ea"):
    """
    Plot the evolution of the EA algorithm's cost over generations for each dataset.

    Parameters:
        ea_progressions (dict): Dictionary where keys are filenames and values are lists of costs per generation.
        output_dir (str): Directory where the plots will be saved.
    """
    import os
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    for filename, progression in ea_progressions.items():
        plt.figure(figsize=(10, 6))
        plt.plot(progression, label='Best Cost')
        plt.title(f'EA Cost Progression for {filename}')
        plt.xlabel('Generation')
        plt.ylabel('Cost (km)')
        plt.legend()
        plt.grid(True)
        plot_filename = os.path.join(output_dir, f"{os.path.basename(filename)}_ea_progression.png")
        plt.savefig(plot_filename)
        plt.close()
        logging.info(f"EA progression plot saved to {plot_filename}")

# %% [markdown]
# ### Plotting Greedy Progression

# %%
def plot_greedy_progress(greedy_progressions, output_dir="plots/greedy"):
    """
    Plot the evolution of the Greedy algorithm's cost over steps for each dataset.

    Parameters:
        greedy_progressions (dict): Dictionary where keys are filenames and values are lists of costs per step.
        output_dir (str): Directory where the plots will be saved.
    """
    import os
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    for filename, progression in greedy_progressions.items():
        plt.figure(figsize=(10, 6))
        plt.plot(progression, label='Cumulative Cost')
        plt.title(f'Greedy Cost Progression for {filename}')
        plt.xlabel('Step')
        plt.ylabel('Cost (km)')
        plt.legend()
        plt.grid(True)
        plot_filename = os.path.join(output_dir, f"{os.path.basename(filename)}_greedy_progression.png")
        plt.savefig(plot_filename)
        plt.close()
        logging.info(f"Greedy progression plot saved to {plot_filename}")

# %% [markdown]
# ### Executing the Plotting Functions

# %%
# Plot the progression of EA
plot_ea_progress(ea_progressions)

# Plot the progression of Greedy
plot_greedy_progress(greedy_progressions)

print("Plotting completed. Check the 'plots' directory for the generated graphs.")
# Out:
# INFO:root:EA progression plot saved to plots/ea/italy.csv_ea_progression.png
# INFO:root:EA progression plot saved to plots/ea/vanuatu.csv_ea_progression.png
# INFO:root:EA progression plot saved to plots/ea/russia.csv_ea_progression.png
# INFO:root:EA progression plot saved to plots/ea/us.csv_ea_progression.png
# INFO:root:EA progression plot saved to plots/ea/china.csv_ea_progression.png
# INFO:root:Greedy progression plot saved to plots/greedy/italy.csv_greedy_progression.png
# INFO:root:Greedy progression plot saved to plots/greedy/vanuatu.csv_greedy_progression.png
# INFO:root:Greedy progression plot saved to plots/greedy/russia.csv_greedy_progression.png
# INFO:root:Greedy progression plot saved to plots/greedy/us.csv_greedy_progression.png
# INFO:root:Greedy progression plot saved to plots/greedy/china.csv_greedy_progression.png
# Plotting completed. Check the 'plots' directory for the generated graphs.
